# %% [markdown]
# # import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
l1 = pd.read_csv('1_left.csv', index_col=0, parse_dates=['time'], infer_datetime_format=True)
r1 = pd.read_csv('1_right.csv', index_col=0, parse_dates=['time'], infer_datetime_format=True)
l2 = pd.read_csv('2_left.csv', index_col=0, parse_dates=['time'], infer_datetime_format=True)
r2 = pd.read_csv('2_right.csv', index_col=0, parse_dates=['time'], infer_datetime_format=True)

# %%
l1.head()
# Out:
#               공정명  product        date          model_name     A      V     G  \
# 0  PLASMA W/D 1호기      408  2021-11-30  MAVERICK (RWD/FWD)  51.2  21.76  7.23
# 1  PLASMA W/D 1호기      407  2021-11-30  MAVERICK (RWD/FWD)  51.2  21.71  7.23
# 2  PLASMA W/D 1호기      406  2021-11-30  MAVERICK (RWD/FWD)  51.2  21.71  7.23
# 3  PLASMA W/D 1호기      405  2021-11-30  MAVERICK (RWD/FWD)  51.2  21.71  7.23
# 4  PLASMA W/D 1호기      404  2021-11-30  MAVERICK (RWD/FWD)  51.2  21.75  7.22
#
#      T estimate  tip_cum  NUM(EA)                time
# 0  7.3     GOOD    42897       77 2021-11-30 17:53:02
# 1  7.2     GOOD    42896       76 2021-11-30 17:52:47
# 2  7.2     GOOD    42895       76 2021-11-30 17:52:32
# 3  7.2     GOOD    42894       76 2021-11-30 17:52:17
# 4  7.3     GOOD    42893       77 2021-11-30 17:52:02

# %%
plt.figure(figsize=(20,10))
print(sns.stripplot(y=l1['product'], x=l1['estimate']).set_title('1호기 Left'))
plt.figure(figsize=(20,10))
print(sns.stripplot(y=r1['product'], x=r1['estimate']).set_title('1호기 right'))
plt.figure(figsize=(20,10))
print(sns.stripplot(y=l2['product'], x=l2['estimate']).set_title('2호기 Left'))
plt.figure(figsize=(20,10))
print(sns.stripplot(y=r2['product'], x=r2['estimate']).set_title('2호기 right'))
# Out:
# Text(0.5, 1.0, '1호기 Left')
# Text(0.5, 1.0, '1호기 right')
# Text(0.5, 1.0, '2호기 Left')
# Text(0.5, 1.0, '2호기 right')

# %%
plt.figure(figsize=(20,10))
print(sns.stripplot(y=l1['A'], x=l1['estimate']).set_title('1호기 Left'))
plt.figure(figsize=(20,10))
print(sns.stripplot(y=r1['A'], x=r1['estimate']).set_title('1호기 right'))
plt.figure(figsize=(20,10))
print(sns.stripplot(y=l2['A'], x=l2['estimate']).set_title('2호기 Left'))
plt.figure(figsize=(20,10))
print(sns.stripplot(y=r2['A'], x=r2['estimate']).set_title('2호기 right'))
# Out:
# Text(0.5, 1.0, '1호기 Left')
# Text(0.5, 1.0, '1호기 right')
# Text(0.5, 1.0, '2호기 Left')
# Text(0.5, 1.0, '2호기 right')

# %%
plt.figure(figsize=(20,10))
print(sns.stripplot(y=l1['V'], x=l1['estimate']).set_title('1호기 Left'))
plt.figure(figsize=(20,10))
print(sns.stripplot(y=r1['V'], x=r1['estimate']).set_title('1호기 right'))
plt.figure(figsize=(20,10))
print(sns.stripplot(y=l2['V'], x=l2['estimate']).set_title('2호기 Left'))
plt.figure(figsize=(20,10))
print(sns.stripplot(y=r2['V'], x=r2['estimate']).set_title('2호기 right'))
# Out:
# Text(0.5, 1.0, '1호기 Left')
# Text(0.5, 1.0, '1호기 right')
# Text(0.5, 1.0, '2호기 Left')
# Text(0.5, 1.0, '2호기 right')

# %%
plt.figure(figsize=(20,10))
print(sns.stripplot(y=l1['G'], x=l1['estimate']).set_title('1호기 Left'))
plt.figure(figsize=(20,10))
print(sns.stripplot(y=r1['G'], x=r1['estimate']).set_title('1호기 right'))
plt.figure(figsize=(20,10))
print(sns.stripplot(y=l2['G'], x=l2['estimate']).set_title('2호기 Left'))
plt.figure(figsize=(20,10))
print(sns.stripplot(y=r2['G'], x=r2['estimate']).set_title('2호기 right'))
# Out:
# Text(0.5, 1.0, '1호기 Left')
# Text(0.5, 1.0, '1호기 right')
# Text(0.5, 1.0, '2호기 Left')
# Text(0.5, 1.0, '2호기 right')

# %%
plt.figure(figsize=(20,10))
print(sns.stripplot(y=l1['T'], x=l1['estimate']).set_title('1호기 Left'))
plt.figure(figsize=(20,10))
print(sns.stripplot(y=r1['T'], x=r1['estimate']).set_title('1호기 right'))
plt.figure(figsize=(20,10))
print(sns.stripplot(y=l2['T'], x=l2['estimate']).set_title('2호기 Left'))
plt.figure(figsize=(20,10))
print(sns.stripplot(y=r2['T'], x=r2['estimate']).set_title('2호기 right'))
# Out:
# Text(0.5, 1.0, '1호기 Left')
# Text(0.5, 1.0, '1호기 right')
# Text(0.5, 1.0, '2호기 Left')
# Text(0.5, 1.0, '2호기 right')

# %%
plt.figure(figsize=(20,10))
print(sns.stripplot(y=l1['NUM(EA)'], x=l1['estimate']).set_title('1호기 Left'))
plt.figure(figsize=(20,10))
print(sns.stripplot(y=r1['NUM(EA)'], x=r1['estimate']).set_title('1호기 right'))
plt.figure(figsize=(20,10))
print(sns.stripplot(y=l2['NUM(EA)'], x=l2['estimate']).set_title('2호기 Left'))
plt.figure(figsize=(20,10))
print(sns.stripplot(y=r2['NUM(EA)'], x=r2['estimate']).set_title('2호기 right'))
# Out:
# Text(0.5, 1.0, '1호기 Left')
# Text(0.5, 1.0, '1호기 right')
# Text(0.5, 1.0, '2호기 Left')
# Text(0.5, 1.0, '2호기 right')

# %%
l1.sort_values(by='time', inplace=True)
l2.sort_values(by='time', inplace=True)
r1.sort_values(by='time', inplace=True)
r2.sort_values(by='time', inplace=True)

# %%
log_list = ['product', 'A', 'V', 'G', 'T', 'tip_cum', 'NUM(EA)']

# %%
plt.figure(figsize=(20,10))
sns.heatmap(np.log(l1[log_list]).corr(), annot=True).set_title('1호기 Left')
plt.figure(figsize=(20,10))
sns.heatmap(np.log(r1[log_list]).corr(), annot=True).set_title('1호기 Right')
plt.figure(figsize=(20,10))
sns.heatmap(np.log(l2[log_list]).corr(), annot=True).set_title('2호기 Left')
plt.figure(figsize=(20,10))
sns.heatmap(np.log(r2[log_list]).corr(), annot=True).set_title('2호기 Right')
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/deeplearn/lib/python3.9/site-packages/pandas/core/internals/blocks.py:402: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# /opt/homebrew/Caskroom/miniforge/base/envs/deeplearn/lib/python3.9/site-packages/pandas/core/internals/blocks.py:402: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# Text(0.5, 1.0, '2호기 Right')

# %%
plt.figure(figsize=(20,10))
sns.heatmap(np.sqrt(l1[log_list]).corr(), annot=True).set_title('1호기 Left')
plt.figure(figsize=(20,10))
sns.heatmap(np.sqrt(r1[log_list]).corr(), annot=True).set_title('1호기 Right')
plt.figure(figsize=(20,10))
sns.heatmap(np.sqrt(l2[log_list]).corr(), annot=True).set_title('2호기 Left')
plt.figure(figsize=(20,10))
sns.heatmap(np.sqrt(r2[log_list]).corr(), annot=True).set_title('2호기 Right')
# Out:
# Text(0.5, 1.0, '2호기 Right')

# %%
plt.figure(figsize=(20,10))
sns.heatmap(l1[log_list].corr(), annot=True).set_title('1호기 Left')
plt.figure(figsize=(20,10))
sns.heatmap(r1[log_list].corr(), annot=True).set_title('1호기 Right')
plt.figure(figsize=(20,10))
sns.heatmap(l2[log_list].corr(), annot=True).set_title('2호기 Left')
plt.figure(figsize=(20,10))
sns.heatmap(r2[log_list].corr(), annot=True).set_title('2호기 Right')
# Out:
# Text(0.5, 1.0, '2호기 Right')
