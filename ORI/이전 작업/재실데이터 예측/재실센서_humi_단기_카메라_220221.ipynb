# %% [markdown]
# #**단기예측 모델 설계 방향**
# **1. 재실인원 데이터 추가한 다변량 단기 모델(습도, 재실인원)**
# 재실 인원을 카메라로 예측한 데이터로 모델 설계
# - 다변량 단기 예측 모델
#  - 재실인원 추가
#  - 다변량모델 (습도, 재실인원)
#  - 기본 모델인 LSTM으로 인원 예측이 잘 되는지 먼저 확인
# - 50분 데이터로 10분의 재실인원 예측
# - 예측이 잘된다면 다른 모델로 변경하여 예측할 계획
#
# 1분 단위 리샘플링

# %%
# !pip install PyMySQL
# Out:
# Collecting PyMySQL
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 656 kB/s
# Installing collected packages: PyMySQL
# Successfully installed PyMySQL-1.0.2

# %%
import pymysql

# %%
occupancy_db = pymysql.connect(
    user='datacollection', 
    passwd='collection2021!@', 
    host='121.156.90.144', 
    db='db_datacollection', 
    charset='utf8'
)

# %%
cursor = occupancy_db.cursor(pymysql.cursors.DictCursor)

# %%
sql = "Show Tables;"
cursor.execute(sql)
show = cursor.fetchall()
show
# Out:
# [{'Tables_in_db_datacollection': 'dc_building'},
#  {'Tables_in_db_datacollection': 'dc_device'},
#  {'Tables_in_db_datacollection': 'dc_floor'},
#  {'Tables_in_db_datacollection': 'dc_long_term'},
#  {'Tables_in_db_datacollection': 'dc_people_cnt'},
#  {'Tables_in_db_datacollection': 'dc_pro_mode_define'},
#  {'Tables_in_db_datacollection': 'dc_pro_module'},
#  {'Tables_in_db_datacollection': 'dc_sensor'},
#  {'Tables_in_db_datacollection': 'dc_sensor_data_arduino_1'},
#  {'Tables_in_db_datacollection': 'dc_sensor_data_arduino_1_name'},
#  {'Tables_in_db_datacollection': 'dc_sensor_data_composite_1'},
#  {'Tables_in_db_datacollection': 'dc_sensor_data_temp_camera_1'},
#  {'Tables_in_db_datacollection': 'dc_sensor_data_temp_camera_info'},
#  {'Tables_in_db_datacollection': 'dc_sensor_define'},
#  {'Tables_in_db_datacollection': 'dc_server'},
#  {'Tables_in_db_datacollection': 'dc_short_term'},
#  {'Tables_in_db_datacollection': 'dc_spot'},
#  {'Tables_in_db_datacollection': 'dc_unit_define'},
#  {'Tables_in_db_datacollection': 'dc_vw_origin_code'},
#  {'Tables_in_db_datacollection': 'se_device_temp_cam_log'},
#  {'Tables_in_db_datacollection': 'se_device_temp_cam_log1'},
#  {'Tables_in_db_datacollection': 'se_device_temp_cam_log_copy'},
#  {'Tables_in_db_datacollection': 'se_jaeseok_zone'},
#  {'Tables_in_db_datacollection': 'se_jaeseok_zone1'},
#  {'Tables_in_db_datacollection': 'se_peoplecount_log'},
#  {'Tables_in_db_datacollection': 'tb_incom'},
#  {'Tables_in_db_datacollection': 'tb_jaeseok_onezone'},
#  {'Tables_in_db_datacollection': 'vw_check_incom'},
#  {'Tables_in_db_datacollection': 'vw_data_composite'},
#  {'Tables_in_db_datacollection': 'vw_data_composite_adhd'},
#  {'Tables_in_db_datacollection': 'vw_data_in_check'},
#  {'Tables_in_db_datacollection': 'vw_data_temp_camera'},
#  {'Tables_in_db_datacollection': 'vw_get_dev_module'},
#  {'Tables_in_db_datacollection': 'vw_get_sensor_module'},
#  {'Tables_in_db_datacollection': 'vw_location'},
#  {'Tables_in_db_datacollection': 'vw_sensor_define'}]

# %%
sql = "SELECT sdata_credate, sdata_humi FROM vw_data_composite WHERE sdata_modbus_id=1;"
cursor.execute(sql)
data = cursor.fetchall()

# %%
# tcl_idx, tci_idx, people, changepeople, reg_dte 
sql1 = "SELECT changepeople, reg_dte FROM se_device_temp_cam_log1;"
cursor.execute(sql1)
data1 = cursor.fetchall()

# %%
import pandas as pd

data = pd.DataFrame(data)
data1 = pd.DataFrame(data1)

# %%
# data.to_csv('occupancy_co2_20220217.csv')
# data2.to_csv('occupancy_all_20220222.csv')

# %%
data.rename(columns={'sdata_credate': 'datetime'},inplace=True)
data1.rename(columns={'reg_dte': 'datetime'},inplace=True)

# %%
data['datetime'] = pd.to_datetime(data['datetime'])
data1['datetime'] = pd.to_datetime(data1['datetime'])

# %%
data.set_index('datetime', inplace=True)
data1.set_index('datetime', inplace=True)

# %%
data = data.resample('1T').first()
data=data.loc['2022-02-11 16:32:00':]

# %%
data1 = data1.resample('1T').first()

# %%
print(data)
print(data1)
# Out:
#                      sdata_humi
# datetime
# 2022-02-11 16:32:00       20.02
# 2022-02-11 16:33:00       19.99
# 2022-02-11 16:34:00       20.09
# 2022-02-11 16:35:00       20.47
# 2022-02-11 16:36:00       20.16
# ...                         ...
# 2022-02-28 15:42:00       20.44
# 2022-02-28 15:43:00       20.39
# 2022-02-28 15:44:00       20.56
# 2022-02-28 15:45:00       20.52
# 2022-02-28 15:46:00       20.45
#
# [24435 rows x 1 columns]
#                      changepeople
# datetime
# 2022-02-11 16:32:00           0.0
# 2022-02-11 16:33:00           0.0
# 2022-02-11 16:34:00           NaN
# 2022-02-11 16:35:00           NaN
# 2022-02-11 16:36:00           NaN
# ...                           ...
# 2022-02-28 15:43:00           5.0
# 2022-02-28 15:44:00           5.0
# 2022-02-28 15:45:00           5.0
# 2022-02-28 15:46:00           5.0
# 2022-02-28 15:47:00           5.0
#
# [24436 rows x 1 columns]

# %%
merge_df = pd.merge(data, data1, left_index=True, right_index=True, how='left')
merge_df
# Out:
#                      sdata_humi  changepeople
# datetime
# 2022-02-11 16:32:00       20.02           0.0
# 2022-02-11 16:33:00       19.99           0.0
# 2022-02-11 16:34:00       20.09           NaN
# 2022-02-11 16:35:00       20.47           NaN
# 2022-02-11 16:36:00       20.16           NaN
# ...                         ...           ...
# 2022-02-28 15:42:00       20.44           5.0
# 2022-02-28 15:43:00       20.39           5.0
# 2022-02-28 15:44:00       20.56           5.0
# 2022-02-28 15:45:00       20.52           5.0
# 2022-02-28 15:46:00       20.45           5.0
#
# [24435 rows x 2 columns]

# %%
merge_df.fillna(0, inplace=True)

# %%
merge_df['changepeople'].value_counts()
# Out:
#  0.0     12258
# -1.0      3885
#  1.0      1826
# -2.0      1252
#  5.0      1085
#  7.0       944
#  6.0       817
#  4.0       631
#  3.0       535
#  2.0       473
#  8.0       358
#  9.0       177
#  10.0      117
#  12.0       51
#  11.0       26
# Name: changepeople, dtype: int64

# %%
# 인원 수가 마이너스가 나온 경우, 0으로 맞춰줌
for i in range(len(merge_df)):
    if merge_df['changepeople'][i]< 0:
        merge_df['changepeople'][i]=0

# %%
merge_df['changepeople'].value_counts()
# Out:
# 0.0     17395
# 1.0      1826
# 5.0      1085
# 7.0       944
# 6.0       817
# 4.0       631
# 3.0       535
# 2.0       473
# 8.0       358
# 9.0       177
# 10.0      117
# 12.0       51
# 11.0       26
# Name: changepeople, dtype: int64

# %% [markdown]
# # 카메라 기반 재실 데이터 그래프
# - 습도, 재실인원

# %%
import matplotlib.pyplot as plt

merge_df.plot(subplots=True, grid=True, 
           figsize=(26, 4), fontsize=18,
           title='humi & people change data visualization')
plt.show()

# %% [markdown]
# ## 습도 데이터로 단변량 예측

# %%
from keras.models import load_model
import numpy as np

# %%
# 재실밀도 데이터
df = merge_df
column_indices = {name: i for i, name in enumerate(df.columns)}

n = len(df)
train_df = df[0:int(n*0.7)]
val_df = df[int(n*0.7):int(n*0.9)]
test_df = df[int(n*0.9):]

num_features = df.shape[1]

# %%
class WindowGenerator():
  def __init__(self, input_width, label_width, shift,
               train_df=train_df, val_df=val_df, test_df=test_df,
               label_columns=None):
    # Store the raw data.
    self.train_df = train_df
    self.val_df = val_df
    self.test_df = test_df

    # Work out the label column indices.
    self.label_columns = label_columns
    if label_columns is not None:
      self.label_columns_indices = {name: i for i, name in
                                    enumerate(label_columns)}
    self.column_indices = {name: i for i, name in
                           enumerate(train_df.columns)}

    # Work out the window parameters.
    self.input_width = input_width
    self.label_width = label_width
    self.shift = shift

    self.total_window_size = input_width + shift

    self.input_slice = slice(0, input_width)
    self.input_indices = np.arange(self.total_window_size)[self.input_slice]

    self.label_start = self.total_window_size - self.label_width
    self.labels_slice = slice(self.label_start, None)
    self.label_indices = np.arange(self.total_window_size)[self.labels_slice]

  def __repr__(self):
    return '\n'.join([
        f'Total window size: {self.total_window_size}',
        f'Input indices: {self.input_indices}',
        f'Label indices: {self.label_indices}',
        f'Label column name(s): {self.label_columns}'])

# %%
w1 = WindowGenerator(input_width=50, label_width=1, shift=50,
                         label_columns=['sdata_humi', 'changepeople'])

# %%
w2 = WindowGenerator(input_width=10, label_width=1, shift=1,
                         label_columns=['sdata_humi','changepeople'])

# %%
def split_window(self, features):
  inputs = features[:, self.input_slice, :]
  labels = features[:, self.labels_slice, :]
  if self.label_columns is not None:
    labels = tf.stack(
        [labels[:, :, self.column_indices[name]] for name in self.label_columns],
        axis=-1)

  # Slicing doesn't preserve static shape information, so set the shapes
  # manually. This way the `tf.data.Datasets` are easier to inspect.
  inputs.set_shape([None, self.input_width, None])
  labels.set_shape([None, self.label_width, None])

  return inputs, labels

WindowGenerator.split_window = split_window

# %%
import tensorflow as tf

# Stack three slices, the length of the total window:
window = tf.stack([np.array(train_df[:w2.total_window_size]),
                           np.array(train_df[100:100+w2.total_window_size]),
                           np.array(train_df[200:200+w2.total_window_size])])

inputs, labels = w2.split_window(window)

print('Temperature shapes are: (batch, time, features)')
print(f'Window shape: {window.shape}')
print(f'Inputs shape: {inputs.shape}')
print(f'labels shape: {labels.shape}\n')
# Out:
# Temperature shapes are: (batch, time, features)
# Window shape: (3, 11, 2)
# Inputs shape: (3, 10, 2)
# labels shape: (3, 1, 2)

# %%
w2.example = inputs, labels

# %%
# humi
def humi_plot(self, model=None, plot_col='sdata_humi', max_subplots=3):
  inputs, labels = self.example
  plt.figure(figsize=(20, 10))
  plot_col_index = self.column_indices[plot_col]
  max_n = min(max_subplots, len(inputs))
  for n in range(max_n):
    plt.subplot(3, 1, n+1)
    plt.ylabel(f'{plot_col}')
    plt.plot(self.input_indices, inputs[n, :, plot_col_index],
             label='Inputs', marker='.', zorder=-10)

    if self.label_columns:
      label_col_index = self.label_columns_indices.get(plot_col, None)
    else:
      label_col_index = plot_col_index

    if label_col_index is None:
      continue

    plt.scatter(self.label_indices, labels[n, :, label_col_index],
                edgecolors='k', label='Labels', c='#2ca02c', s=64)
    if model is not None:
      predictions = model(inputs)
      plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                  marker='X', edgecolors='k', label='Predictions',
                  c='#ff7f0e', s=64)

    if n == 0:
      plt.legend()

  plt.xlabel('Time [1m]')

WindowGenerator.humi_plot = humi_plot

# change people
def changepeople_plot(self, model=None, plot_col='changepeople', max_subplots=3):
  inputs, labels = self.example
  plt.figure(figsize=(20, 10))
  plot_col_index = self.column_indices[plot_col]
  max_n = min(max_subplots, len(inputs))
  for n in range(max_n):
    plt.subplot(3, 1, n+1)
    plt.ylabel(f'{plot_col}')
    plt.plot(self.input_indices, inputs[n, :, plot_col_index],
             label='Inputs', marker='.', zorder=-10)

    if self.label_columns:
      label_col_index = self.label_columns_indices.get(plot_col, None)
    else:
      label_col_index = plot_col_index

    if label_col_index is None:
      continue

    plt.scatter(self.label_indices, labels[n, :, label_col_index],
                edgecolors='k', label='Labels', c='#2ca02c', s=64)
    if model is not None:
      predictions = model(inputs)
      plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                  marker='X', edgecolors='k', label='Predictions',
                  c='#ff7f0e', s=64)

    if n == 0:
      plt.legend()

  plt.xlabel('Time [1m]')

WindowGenerator.changepeople_plot = changepeople_plot

# %%
def make_dataset(self, data):
  data = np.array(data, dtype=np.float32)
  ds = tf.keras.preprocessing.timeseries_dataset_from_array(
      data=data,
      targets=None,
      sequence_length=self.total_window_size,
      sequence_stride=1,
      shuffle=True,
      batch_size=32,)

  ds = ds.map(self.split_window)

  return ds

WindowGenerator.make_dataset = make_dataset

# %%
@property
def train(self):
  return self.make_dataset(self.train_df)

@property
def val(self):
  return self.make_dataset(self.val_df)

@property
def test(self):
  return self.make_dataset(self.test_df)

@property
def example(self):
  """Get and cache an example batch of `inputs, labels` for plotting."""
  result = getattr(self, '_example', None)
  if result is None:
    # No example batch was found, so get one from the `.train` dataset
    result = next(iter(self.train))
    # And cache it for next time
    self._example = result
  return result

WindowGenerator.train = train
WindowGenerator.val = val
WindowGenerator.test = test
WindowGenerator.example = example

# %%
w2.train.element_spec
# Out:
# (TensorSpec(shape=(None, 10, 2), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None, 1, 2), dtype=tf.float32, name=None))

# %%
OUT_STEPS=10
multi_window = WindowGenerator(input_width=50,
                                   label_width=OUT_STEPS,
                                   shift=OUT_STEPS)

multi_window
multi_window.humi_plot()

# %%
MAX_EPOCHS = 100

def compile_and_fit(model, window, patience=5):
  early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                    patience=patience,
                                                    mode='min')

  model.compile(loss=tf.losses.MeanSquaredError(),
                optimizer=tf.optimizers.Adam(),
                metrics=[tf.metrics.MeanAbsoluteError()])

  history = model.fit(window.train, epochs=MAX_EPOCHS,
                      validation_data=window.val,
                      callbacks=[early_stopping])
  return history

# %% [markdown]
# ### 습도

# %%
humi_multi_lstm_model = tf.keras.Sequential([
    tf.keras.layers.LSTM(128, return_sequences=False),
    tf.keras.layers.Dense(OUT_STEPS*num_features,
                          kernel_initializer=tf.initializers.zeros),
    tf.keras.layers.Reshape([OUT_STEPS, num_features])
])

humi_history = compile_and_fit(humi_multi_lstm_model, multi_window)

humi_multi_val_performance = {}
humi_multi_performance = {}
humi_multi_val_performance['LSTM'] = humi_multi_lstm_model.evaluate(multi_window.val)
humi_multi_performance['LSTM'] = humi_multi_lstm_model.evaluate(multi_window.test, verbose=0)

multi_window.humi_plot(humi_multi_lstm_model)
# Out:
# Epoch 1/100
# 533/533 [==============================] - 44s 71ms/step - loss: 32.6601 - mean_absolute_error: 3.3401 - val_loss: 2.0385 - val_mean_absolute_error: 1.0639
# Epoch 2/100
# 533/533 [==============================] - 32s 59ms/step - loss: 0.7453 - mean_absolute_error: 0.4373 - val_loss: 0.3338 - val_mean_absolute_error: 0.2345
# Epoch 3/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.2130 - mean_absolute_error: 0.2097 - val_loss: 0.2824 - val_mean_absolute_error: 0.2425
# Epoch 4/100
# 533/533 [==============================] - 33s 62ms/step - loss: 0.1698 - mean_absolute_error: 0.1792 - val_loss: 0.2595 - val_mean_absolute_error: 0.2119
# Epoch 5/100
# 533/533 [==============================] - 31s 59ms/step - loss: 0.1585 - mean_absolute_error: 0.1710 - val_loss: 0.2544 - val_mean_absolute_error: 0.2110
# Epoch 6/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.1568 - mean_absolute_error: 0.1761 - val_loss: 0.2485 - val_mean_absolute_error: 0.2014
# Epoch 7/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.1510 - mean_absolute_error: 0.1664 - val_loss: 0.2457 - val_mean_absolute_error: 0.2006
# Epoch 8/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.1489 - mean_absolute_error: 0.1683 - val_loss: 0.2408 - val_mean_absolute_error: 0.1826
# Epoch 9/100
# 533/533 [==============================] - 31s 59ms/step - loss: 0.1454 - mean_absolute_error: 0.1593 - val_loss: 0.2422 - val_mean_absolute_error: 0.1952
# Epoch 10/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.1443 - mean_absolute_error: 0.1626 - val_loss: 0.2450 - val_mean_absolute_error: 0.2271
# Epoch 11/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.1435 - mean_absolute_error: 0.1642 - val_loss: 0.2348 - val_mean_absolute_error: 0.1847
# Epoch 12/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.1409 - mean_absolute_error: 0.1595 - val_loss: 0.2635 - val_mean_absolute_error: 0.2699
# Epoch 13/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.1402 - mean_absolute_error: 0.1605 - val_loss: 0.2414 - val_mean_absolute_error: 0.2061
# Epoch 14/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.1405 - mean_absolute_error: 0.1631 - val_loss: 0.2392 - val_mean_absolute_error: 0.1821
# Epoch 15/100
# 533/533 [==============================] - 31s 59ms/step - loss: 0.1374 - mean_absolute_error: 0.1552 - val_loss: 0.2385 - val_mean_absolute_error: 0.2017
# Epoch 16/100
# 533/533 [==============================] - 31s 59ms/step - loss: 0.1380 - mean_absolute_error: 0.1548 - val_loss: 0.2367 - val_mean_absolute_error: 0.1974
# 151/151 [==============================] - 3s 20ms/step - loss: 0.2367 - mean_absolute_error: 0.1974

# %%
multi_window.changepeople_plot(humi_multi_lstm_model)

# %%
humi_multi_lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               67072
#
#  dense (Dense)               (None, 20)                2580
#
#  reshape (Reshape)           (None, 10, 2)             0
#
# =================================================================
# Total params: 69,652
# Trainable params: 69,652
# Non-trainable params: 0
# _________________________________________________________________

# %%
humi_multi_lstm_model.evaluate(multi_window.test)
# Out:
# 75/75 [==============================] - 2s 20ms/step - loss: 0.2311 - mean_absolute_error: 0.1893
# [0.2311471551656723, 0.18930649757385254]

# %%
print('_________________________________________________________________')
print('Model evaluate')
print('=================================================================')
print('Loss: ', humi_multi_performance['LSTM'][0])
print('MAE(Mean Absolute Error): ', humi_multi_performance['LSTM'][1])
print('=================================================================')
# Out:
# _________________________________________________________________
# Model evaluate
# =================================================================
# Loss:  0.2311471551656723
# MAE(Mean Absolute Error):  0.18930645287036896
# =================================================================

# %%
# 6 훈련 과정 시각화 (MAE)
plt.plot(humi_history.history['mean_absolute_error'])
plt.plot(humi_history.history['val_mean_absolute_error'])
plt.title('Model MAE(mean absolute error)')
plt.xlabel('Epoch')
plt.ylabel('mean_absolute_error')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# 7 훈련 과정 시각화 (손실)
plt.plot(humi_history.history['loss'])
plt.plot(humi_history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# # 모델 저장
# humi_multi_lstm_model.save('humi_multi_lstm_model.h5')

# %%
changepeople_multi_lstm_model = tf.keras.Sequential([
    tf.keras.layers.LSTM(128, return_sequences=False),
    tf.keras.layers.Dense(OUT_STEPS*num_features,
                          kernel_initializer=tf.initializers.zeros),
    tf.keras.layers.Reshape([OUT_STEPS, num_features])
])

changepeople_history = compile_and_fit(changepeople_multi_lstm_model, multi_window)

changepeople_multi_val_performance = {}
changepeople_multi_performance = {}
changepeople_multi_val_performance['LSTM'] = changepeople_multi_lstm_model.evaluate(multi_window.val)
changepeople_multi_performance['LSTM'] = changepeople_multi_lstm_model.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/100
# 533/533 [==============================] - 33s 58ms/step - loss: 35.6478 - mean_absolute_error: 3.8082 - val_loss: 5.2061 - val_mean_absolute_error: 1.7617
# Epoch 2/100
# 533/533 [==============================] - 31s 58ms/step - loss: 1.8868 - mean_absolute_error: 0.7816 - val_loss: 0.4975 - val_mean_absolute_error: 0.3727
# Epoch 3/100
# 533/533 [==============================] - 32s 59ms/step - loss: 0.3064 - mean_absolute_error: 0.2720 - val_loss: 0.3161 - val_mean_absolute_error: 0.2590
# Epoch 4/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.1882 - mean_absolute_error: 0.1910 - val_loss: 0.2675 - val_mean_absolute_error: 0.2100
# Epoch 5/100
# 533/533 [==============================] - 31s 59ms/step - loss: 0.1640 - mean_absolute_error: 0.1700 - val_loss: 0.2586 - val_mean_absolute_error: 0.2260
# Epoch 6/100
# 533/533 [==============================] - 31s 59ms/step - loss: 0.1584 - mean_absolute_error: 0.1723 - val_loss: 0.2524 - val_mean_absolute_error: 0.2075
# Epoch 7/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.1533 - mean_absolute_error: 0.1650 - val_loss: 0.2472 - val_mean_absolute_error: 0.2132
# Epoch 8/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.1499 - mean_absolute_error: 0.1631 - val_loss: 0.2443 - val_mean_absolute_error: 0.1938
# Epoch 9/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.1493 - mean_absolute_error: 0.1642 - val_loss: 0.2424 - val_mean_absolute_error: 0.2085
# Epoch 10/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.1476 - mean_absolute_error: 0.1599 - val_loss: 0.2403 - val_mean_absolute_error: 0.1927
# Epoch 11/100
# 533/533 [==============================] - 32s 59ms/step - loss: 0.1466 - mean_absolute_error: 0.1630 - val_loss: 0.2568 - val_mean_absolute_error: 0.2492
# Epoch 12/100
# 533/533 [==============================] - 31s 59ms/step - loss: 0.1456 - mean_absolute_error: 0.1600 - val_loss: 0.2344 - val_mean_absolute_error: 0.1849
# Epoch 13/100
# 533/533 [==============================] - 31s 59ms/step - loss: 0.1438 - mean_absolute_error: 0.1584 - val_loss: 0.2445 - val_mean_absolute_error: 0.2172
# Epoch 14/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.1419 - mean_absolute_error: 0.1557 - val_loss: 0.2356 - val_mean_absolute_error: 0.1778
# Epoch 15/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.1417 - mean_absolute_error: 0.1551 - val_loss: 0.2416 - val_mean_absolute_error: 0.1995
# Epoch 16/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.1410 - mean_absolute_error: 0.1584 - val_loss: 0.2568 - val_mean_absolute_error: 0.2549
# Epoch 17/100
# 533/533 [==============================] - 31s 57ms/step - loss: 0.1412 - mean_absolute_error: 0.1593 - val_loss: 0.2325 - val_mean_absolute_error: 0.1819
# Epoch 18/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.1406 - mean_absolute_error: 0.1605 - val_loss: 0.2331 - val_mean_absolute_error: 0.1863
# Epoch 19/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.1383 - mean_absolute_error: 0.1554 - val_loss: 0.2378 - val_mean_absolute_error: 0.2073
# Epoch 20/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.1379 - mean_absolute_error: 0.1562 - val_loss: 0.2345 - val_mean_absolute_error: 0.1832
# Epoch 21/100
# 533/533 [==============================] - 32s 59ms/step - loss: 0.1353 - mean_absolute_error: 0.1504 - val_loss: 0.2468 - val_mean_absolute_error: 0.2135
# Epoch 22/100
# 533/533 [==============================] - 31s 58ms/step - loss: 0.1356 - mean_absolute_error: 0.1545 - val_loss: 0.2339 - val_mean_absolute_error: 0.1869
# 151/151 [==============================] - 3s 20ms/step - loss: 0.2339 - mean_absolute_error: 0.1869

# %%
multi_window.changepeople_plot(changepeople_multi_lstm_model)

# %%
changepeople_multi_lstm_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 128)               67072
#
#  dense_1 (Dense)             (None, 20)                2580
#
#  reshape_1 (Reshape)         (None, 10, 2)             0
#
# =================================================================
# Total params: 69,652
# Trainable params: 69,652
# Non-trainable params: 0
# _________________________________________________________________

# %%
changepeople_multi_lstm_model.evaluate(multi_window.test)
# Out:
# 75/75 [==============================] - 2s 20ms/step - loss: 0.2116 - mean_absolute_error: 0.1757
# [0.21157556772232056, 0.1757040023803711]

# %%
print('_________________________________________________________________')
print('Model evaluate')
print('=================================================================')
print('Loss: ', changepeople_multi_performance['LSTM'][0])
print('MAE(Mean Absolute Error): ', changepeople_multi_performance['LSTM'][1])
print('=================================================================')
# Out:
# _________________________________________________________________
# Model evaluate
# =================================================================
# Loss:  0.21157555282115936
# MAE(Mean Absolute Error):  0.1757040023803711
# =================================================================

# %%
# 6 훈련 과정 시각화 (MAE)
plt.plot(changepeople_history.history['mean_absolute_error'])
plt.plot(changepeople_history.history['val_mean_absolute_error'])
plt.title('Model MAE(mean absolute error)')
plt.xlabel('Epoch')
plt.ylabel('mean_absolute_error')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# 7 훈련 과정 시각화 (손실)
plt.plot(changepeople_history.history['loss'])
plt.plot(changepeople_history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# # 모델 저장
# changepeople_multi_lstm_model.save('humi_changepeople_multi_lstm_model.h5')
