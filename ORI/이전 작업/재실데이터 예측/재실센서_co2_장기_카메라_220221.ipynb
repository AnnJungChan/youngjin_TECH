# %% [markdown]
# #**장기예측 모델 설계 방향**
# **1. 재실인원 데이터 추가한 다변량 단기 모델(co2, 재실인원)**
# 재실 인원을 카메라로 예측한 데이터로 모델 설계
# - 다변량 단기 예측 모델
#  - 재실인원 추가
#  - 다변량모델 (co2, 재실인원)
#  - 기본 모델인 LSTM으로 인원 예측이 잘 되는지 먼저 확인
# - 3일의 데이터로 1일의 재실인원 예측
# - 예측이 잘된다면 다른 모델로 변경하여 예측할 계획
#
# 1분 단위 리샘플링

# %%
# !pip install PyMySQL
# Out:
# Collecting PyMySQL
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 715 kB/s
# Installing collected packages: PyMySQL
# Successfully installed PyMySQL-1.0.2

# %%
import pymysql

# %%
occupancy_db = pymysql.connect(
    user='datacollection', 
    passwd='collection2021!@', 
    host='121.156.90.144', 
    db='db_datacollection', 
    charset='utf8'
)

# %%
cursor = occupancy_db.cursor(pymysql.cursors.DictCursor)

# %%
sql = "Show Tables;"
cursor.execute(sql)
show = cursor.fetchall()
show
# Out:
# [{'Tables_in_db_datacollection': 'dc_building'},
#  {'Tables_in_db_datacollection': 'dc_device'},
#  {'Tables_in_db_datacollection': 'dc_floor'},
#  {'Tables_in_db_datacollection': 'dc_long_term'},
#  {'Tables_in_db_datacollection': 'dc_people_cnt'},
#  {'Tables_in_db_datacollection': 'dc_pro_mode_define'},
#  {'Tables_in_db_datacollection': 'dc_pro_module'},
#  {'Tables_in_db_datacollection': 'dc_sensor'},
#  {'Tables_in_db_datacollection': 'dc_sensor_data_arduino_1'},
#  {'Tables_in_db_datacollection': 'dc_sensor_data_arduino_1_name'},
#  {'Tables_in_db_datacollection': 'dc_sensor_data_composite_1'},
#  {'Tables_in_db_datacollection': 'dc_sensor_data_temp_camera_1'},
#  {'Tables_in_db_datacollection': 'dc_sensor_data_temp_camera_info'},
#  {'Tables_in_db_datacollection': 'dc_sensor_define'},
#  {'Tables_in_db_datacollection': 'dc_server'},
#  {'Tables_in_db_datacollection': 'dc_short_term'},
#  {'Tables_in_db_datacollection': 'dc_spot'},
#  {'Tables_in_db_datacollection': 'dc_unit_define'},
#  {'Tables_in_db_datacollection': 'dc_vw_origin_code'},
#  {'Tables_in_db_datacollection': 'se_device_temp_cam_log'},
#  {'Tables_in_db_datacollection': 'se_device_temp_cam_log1'},
#  {'Tables_in_db_datacollection': 'se_device_temp_cam_log_copy'},
#  {'Tables_in_db_datacollection': 'se_jaeseok_zone'},
#  {'Tables_in_db_datacollection': 'se_jaeseok_zone1'},
#  {'Tables_in_db_datacollection': 'se_peoplecount_log'},
#  {'Tables_in_db_datacollection': 'tb_incom'},
#  {'Tables_in_db_datacollection': 'tb_jaeseok_onezone'},
#  {'Tables_in_db_datacollection': 'vw_check_incom'},
#  {'Tables_in_db_datacollection': 'vw_data_composite'},
#  {'Tables_in_db_datacollection': 'vw_data_composite_adhd'},
#  {'Tables_in_db_datacollection': 'vw_data_in_check'},
#  {'Tables_in_db_datacollection': 'vw_data_temp_camera'},
#  {'Tables_in_db_datacollection': 'vw_get_dev_module'},
#  {'Tables_in_db_datacollection': 'vw_get_sensor_module'},
#  {'Tables_in_db_datacollection': 'vw_location'},
#  {'Tables_in_db_datacollection': 'vw_sensor_define'}]

# %%
sql = "SELECT sdata_credate, sdata_co2 FROM vw_data_composite WHERE sdata_modbus_id=1;"
cursor.execute(sql)
data = cursor.fetchall()

# %%
# tcl_idx, tci_idx, people, changepeople, reg_dte 
sql1 = "SELECT changepeople, reg_dte FROM se_device_temp_cam_log1;"
cursor.execute(sql1)
data1 = cursor.fetchall()

# %%
# tcl_idx, tci_idx, people, changepeople, reg_dte 
sql2 = "SELECT * FROM se_device_temp_cam_log1;"
cursor.execute(sql2)
data2 = cursor.fetchall()

# %%
import pandas as pd

data = pd.DataFrame(data)
data1 = pd.DataFrame(data1)

# %%
data2 = pd.DataFrame(data2)

# %%
# # data.to_csv('occupancy_co2_20220217.csv')
# data2.to_csv('occupancy_all_20220222.csv')

# %%
data.rename(columns={'sdata_credate': 'datetime'},inplace=True)
data1.rename(columns={'reg_dte': 'datetime'},inplace=True)

# %%
data['datetime'] = pd.to_datetime(data['datetime'])
data1['datetime'] = pd.to_datetime(data1['datetime'])

# %%
data.set_index('datetime', inplace=True)
data1.set_index('datetime', inplace=True)

# %%
data = data.resample('1H').first()
data=data.loc['2022-02-11 16:32:00':]

# %%
data1 = data1.resample('1H').first()

# %%
print(data)
print(data1)
# Out:
#                      sdata_co2
# datetime
# 2022-02-11 17:00:00     1070.0
# 2022-02-11 18:00:00      990.0
# 2022-02-11 19:00:00      793.0
# 2022-02-11 20:00:00      703.0
# 2022-02-11 21:00:00      656.0
# ...                        ...
# 2022-03-02 02:00:00      522.0
# 2022-03-02 03:00:00      510.0
# 2022-03-02 04:00:00      497.0
# 2022-03-02 05:00:00      483.0
# 2022-03-02 06:00:00      474.0
#
# [446 rows x 1 columns]
#                      changepeople
# datetime
# 2022-02-11 16:00:00           0.0
# 2022-02-11 17:00:00           0.0
# 2022-02-11 18:00:00           NaN
# 2022-02-11 19:00:00           NaN
# 2022-02-11 20:00:00           NaN
# ...                           ...
# 2022-03-02 02:00:00           1.0
# 2022-03-02 03:00:00           0.0
# 2022-03-02 04:00:00           0.0
# 2022-03-02 05:00:00           0.0
# 2022-03-02 06:00:00           0.0
#
# [447 rows x 1 columns]

# %%
# index 열 개수가 맞지 않아서 인덱스 기준 merge가 불가능
merge_df = pd.merge(data, data1, left_index=True, right_index=True, how='left')
merge_df
# Out:
#                      sdata_co2  changepeople
# datetime
# 2022-02-11 17:00:00     1070.0           0.0
# 2022-02-11 18:00:00      990.0           NaN
# 2022-02-11 19:00:00      793.0           NaN
# 2022-02-11 20:00:00      703.0           NaN
# 2022-02-11 21:00:00      656.0           NaN
# ...                        ...           ...
# 2022-03-02 02:00:00      522.0           1.0
# 2022-03-02 03:00:00      510.0           0.0
# 2022-03-02 04:00:00      497.0           0.0
# 2022-03-02 05:00:00      483.0           0.0
# 2022-03-02 06:00:00      474.0           0.0
#
# [446 rows x 2 columns]

# %%
merge_df.fillna(0, inplace=True)

# %%
merge_df['changepeople'].value_counts()
# Out:
#  0.0     216
# -1.0      63
#  1.0      33
# -2.0      27
#  7.0      22
#  5.0      19
#  6.0      17
#  2.0      16
#  4.0      13
#  8.0       8
#  3.0       7
#  10.0      3
#  9.0       2
# Name: changepeople, dtype: int64

# %%
# 인원 수가 마이너스가 나온 경우, 0으로 맞춰줌
for i in range(len(merge_df)):
    if merge_df['changepeople'][i]< 0:
        merge_df['changepeople'][i]=0

# %%
merge_df['changepeople'].value_counts()
# Out:
# 0.0     306
# 1.0      33
# 7.0      22
# 5.0      19
# 6.0      17
# 2.0      16
# 4.0      13
# 8.0       8
# 3.0       7
# 10.0      3
# 9.0       2
# Name: changepeople, dtype: int64

# %% [markdown]
# # 카메라 기반 재실 데이터 그래프
# - 이산화탄소, 재실인원

# %%
import matplotlib.pyplot as plt

merge_df.plot(subplots=True, grid=True, 
           figsize=(26, 4), fontsize=18,
           title='co2 & people change data visualization')
plt.show()

# %% [markdown]
# ## 이산화탄소 데이터로 단변량 예측

# %%
from keras.models import load_model
import numpy as np

# %%
# 재실밀도 데이터
df = merge_df
column_indices = {name: i for i, name in enumerate(df.columns)}

# n = len(df)
# train_df = df[0:int(n*0.7)]
# val_df = df[int(n*0.7):int(n*0.9)]
# test_df = df[int(n*0.9):]

n = len(df)
train_df = df[0:int(n*0.7)]
val_df = df[int(n*0.7):]

num_features = df.shape[1]

# %%
class WindowGenerator():
  def __init__(self, input_width, label_width, shift,
               train_df=train_df, val_df=val_df,
            #    test_df=test_df,
               label_columns=None):
    # Store the raw data.
    self.train_df = train_df
    self.val_df = val_df
    # self.test_df = test_df

    # Work out the label column indices.
    self.label_columns = label_columns
    if label_columns is not None:
      self.label_columns_indices = {name: i for i, name in
                                    enumerate(label_columns)}
    self.column_indices = {name: i for i, name in
                           enumerate(train_df.columns)}

    # Work out the window parameters.
    self.input_width = input_width
    self.label_width = label_width
    self.shift = shift

    self.total_window_size = input_width + shift

    self.input_slice = slice(0, input_width)
    self.input_indices = np.arange(self.total_window_size)[self.input_slice]

    self.label_start = self.total_window_size - self.label_width
    self.labels_slice = slice(self.label_start, None)
    self.label_indices = np.arange(self.total_window_size)[self.labels_slice]

  def __repr__(self):
    return '\n'.join([
        f'Total window size: {self.total_window_size}',
        f'Input indices: {self.input_indices}',
        f'Label indices: {self.label_indices}',
        f'Label column name(s): {self.label_columns}'])

# %%
w1 = WindowGenerator(input_width=72, label_width=1, shift=72,
                         label_columns=['sdata_co2', 'changepeople'])

# %%
w2 = WindowGenerator(input_width=24, label_width=1, shift=1,
                         label_columns=['sdata_co2','changepeople'])

# %%
def split_window(self, features):
  inputs = features[:, self.input_slice, :]
  labels = features[:, self.labels_slice, :]
  if self.label_columns is not None:
    labels = tf.stack(
        [labels[:, :, self.column_indices[name]] for name in self.label_columns],
        axis=-1)

  # Slicing doesn't preserve static shape information, so set the shapes
  # manually. This way the `tf.data.Datasets` are easier to inspect.
  inputs.set_shape([None, self.input_width, None])
  labels.set_shape([None, self.label_width, None])

  return inputs, labels

WindowGenerator.split_window = split_window

# %%
import tensorflow as tf

# Stack three slices, the length of the total window:
window = tf.stack([np.array(train_df[:w2.total_window_size]),
                           np.array(train_df[90:90+w2.total_window_size]),
                           np.array(train_df[180:180+w2.total_window_size])])

inputs, labels = w2.split_window(window)

print('Temperature shapes are: (batch, time, features)')
print(f'Window shape: {window.shape}')
print(f'Inputs shape: {inputs.shape}')
print(f'labels shape: {labels.shape}\n')
# Out:
# Temperature shapes are: (batch, time, features)
# Window shape: (3, 25, 2)
# Inputs shape: (3, 24, 2)
# labels shape: (3, 1, 2)

# %%
w2.example = inputs, labels

# %%
# co2
def co2_plot(self, model=None, plot_col='sdata_co2', max_subplots=3):
  inputs, labels = self.example
  plt.figure(figsize=(20, 10))
  plot_col_index = self.column_indices[plot_col]
  max_n = min(max_subplots, len(inputs))
  for n in range(max_n):
    plt.subplot(3, 1, n+1)
    plt.ylabel(f'{plot_col}')
    plt.plot(self.input_indices, inputs[n, :, plot_col_index],
             label='Inputs', marker='.', zorder=-10)

    if self.label_columns:
      label_col_index = self.label_columns_indices.get(plot_col, None)
    else:
      label_col_index = plot_col_index

    if label_col_index is None:
      continue

    plt.scatter(self.label_indices, labels[n, :, label_col_index],
                edgecolors='k', label='Labels', c='#2ca02c', s=64)
    if model is not None:
      predictions = model(inputs)
      plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                  marker='X', edgecolors='k', label='Predictions',
                  c='#ff7f0e', s=64)

    if n == 0:
      plt.legend()

  plt.xlabel('Time [1h]')

WindowGenerator.co2_plot = co2_plot

# change people
def changepeople_plot(self, model=None, plot_col='changepeople', max_subplots=3):
  inputs, labels = self.example
  plt.figure(figsize=(20, 10))
  plot_col_index = self.column_indices[plot_col]
  max_n = min(max_subplots, len(inputs))
  for n in range(max_n):
    plt.subplot(3, 1, n+1)
    plt.ylabel(f'{plot_col}')
    plt.plot(self.input_indices, inputs[n, :, plot_col_index],
             label='Inputs', marker='.', zorder=-10)

    if self.label_columns:
      label_col_index = self.label_columns_indices.get(plot_col, None)
    else:
      label_col_index = plot_col_index

    if label_col_index is None:
      continue

    plt.scatter(self.label_indices, labels[n, :, label_col_index],
                edgecolors='k', label='Labels', c='#2ca02c', s=64)
    if model is not None:
      predictions = model(inputs)
      plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                  marker='X', edgecolors='k', label='Predictions',
                  c='#ff7f0e', s=64)

    if n == 0:
      plt.legend()

  plt.xlabel('Time [1h]')

WindowGenerator.changepeople_plot = changepeople_plot

# %%
def make_dataset(self, data):
  data = np.array(data, dtype=np.float32)
  ds = tf.keras.preprocessing.timeseries_dataset_from_array(
      data=data,
      targets=None,
      sequence_length=self.total_window_size,
      sequence_stride=1,
      shuffle=True,
      batch_size=4,)

  ds = ds.map(self.split_window)

  return ds

WindowGenerator.make_dataset = make_dataset

# %%
@property
def train(self):
  return self.make_dataset(self.train_df)

@property
def val(self):
  return self.make_dataset(self.val_df)

@property
def test(self):
  return self.make_dataset(self.test_df)

@property
def example(self):
  """Get and cache an example batch of `inputs, labels` for plotting."""
  result = getattr(self, '_example', None)
  if result is None:
    # No example batch was found, so get one from the `.train` dataset
    result = next(iter(self.train))
    # And cache it for next time
    self._example = result
  return result

WindowGenerator.train = train
WindowGenerator.val = val
WindowGenerator.test = test
WindowGenerator.example = example

# %%
w2.train.element_spec
# Out:
# (TensorSpec(shape=(None, 24, 2), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None, 1, 2), dtype=tf.float32, name=None))

# %%
OUT_STEPS=24
multi_window = WindowGenerator(input_width=72,
                                   label_width=OUT_STEPS,
                                   shift=OUT_STEPS)

multi_window
multi_window.co2_plot()

# %%
MAX_EPOCHS = 200

def compile_and_fit(model, window, patience=5):
  early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_mean_absolute_error',
                                                    patience=patience,
                                                    mode='min')

  model.compile(loss=tf.losses.MeanSquaredError(),
                optimizer=tf.optimizers.Adam(),
                metrics=[tf.metrics.MeanAbsoluteError()])

  history = model.fit(window.train, epochs=MAX_EPOCHS,
                      validation_data=window.val,
                      callbacks=[early_stopping])
  return history

# %% [markdown]
# ### 이산화탄소

# %%
co2_multi_lstm_model = tf.keras.Sequential([
    tf.keras.layers.LSTM(32, return_sequences=False),
    tf.keras.layers.Dense(OUT_STEPS*num_features,
                          kernel_initializer=tf.initializers.zeros),
    tf.keras.layers.Reshape([OUT_STEPS, num_features])
])

co2_history = compile_and_fit(co2_multi_lstm_model, multi_window)

co2_multi_val_performance = {}
co2_multi_performance = {}
co2_multi_val_performance['LSTM'] = co2_multi_lstm_model.evaluate(multi_window.val, verbose=0)
# co2_multi_performance['LSTM'] = co2_multi_lstm_model.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/200
# 55/55 [==============================] - 10s 74ms/step - loss: 235844.9375 - mean_absolute_error: 332.3602 - val_loss: 317694.2500 - val_mean_absolute_error: 375.7207
# Epoch 2/200
# 55/55 [==============================] - 3s 50ms/step - loss: 235484.9062 - mean_absolute_error: 332.1362 - val_loss: 317179.0000 - val_mean_absolute_error: 375.4001
# Epoch 3/200
# 55/55 [==============================] - 3s 50ms/step - loss: 235026.6719 - mean_absolute_error: 331.8423 - val_loss: 316684.5000 - val_mean_absolute_error: 375.0936
# Epoch 4/200
# 55/55 [==============================] - 3s 46ms/step - loss: 234608.1094 - mean_absolute_error: 331.5717 - val_loss: 316226.7812 - val_mean_absolute_error: 374.8173
# Epoch 5/200
# 55/55 [==============================] - 2s 27ms/step - loss: 234209.3438 - mean_absolute_error: 331.3065 - val_loss: 315781.3125 - val_mean_absolute_error: 374.5383
# Epoch 6/200
# 55/55 [==============================] - 1s 27ms/step - loss: 233799.9844 - mean_absolute_error: 331.0242 - val_loss: 315282.5000 - val_mean_absolute_error: 374.2227
# Epoch 7/200
# 55/55 [==============================] - 1s 27ms/step - loss: 233373.0312 - mean_absolute_error: 330.7214 - val_loss: 314830.9375 - val_mean_absolute_error: 373.9287
# Epoch 8/200
# 55/55 [==============================] - 2s 27ms/step - loss: 232975.7812 - mean_absolute_error: 330.4308 - val_loss: 314383.3438 - val_mean_absolute_error: 373.6340
# Epoch 9/200
# 55/55 [==============================] - 2s 29ms/step - loss: 232582.5000 - mean_absolute_error: 330.1396 - val_loss: 313939.8125 - val_mean_absolute_error: 373.3410
# Epoch 10/200
# 55/55 [==============================] - 2s 28ms/step - loss: 232192.6562 - mean_absolute_error: 329.8474 - val_loss: 313499.6875 - val_mean_absolute_error: 373.0479
# Epoch 11/200
# 55/55 [==============================] - 2s 27ms/step - loss: 231806.4375 - mean_absolute_error: 329.5550 - val_loss: 313064.0938 - val_mean_absolute_error: 372.7553
# Epoch 12/200
# 55/55 [==============================] - 2s 28ms/step - loss: 231420.8125 - mean_absolute_error: 329.2633 - val_loss: 312628.0625 - val_mean_absolute_error: 372.4649
# Epoch 13/200
# 55/55 [==============================] - 2s 29ms/step - loss: 231037.4219 - mean_absolute_error: 328.9706 - val_loss: 312194.8438 - val_mean_absolute_error: 372.1723
# Epoch 14/200
# 55/55 [==============================] - 2s 29ms/step - loss: 230655.4688 - mean_absolute_error: 328.6812 - val_loss: 311762.6875 - val_mean_absolute_error: 371.8824
# Epoch 15/200
# 55/55 [==============================] - 2s 28ms/step - loss: 230274.8594 - mean_absolute_error: 328.3922 - val_loss: 311332.2500 - val_mean_absolute_error: 371.5913
# Epoch 16/200
# 55/55 [==============================] - 2s 30ms/step - loss: 229895.2188 - mean_absolute_error: 328.1023 - val_loss: 310902.8750 - val_mean_absolute_error: 371.3037
# Epoch 17/200
# 55/55 [==============================] - 2s 28ms/step - loss: 229517.0625 - mean_absolute_error: 327.8123 - val_loss: 310473.9375 - val_mean_absolute_error: 371.0139
# Epoch 18/200
# 55/55 [==============================] - 2s 28ms/step - loss: 229139.9062 - mean_absolute_error: 327.5227 - val_loss: 310048.0625 - val_mean_absolute_error: 370.7231
# Epoch 19/200
# 55/55 [==============================] - 2s 28ms/step - loss: 228763.4844 - mean_absolute_error: 327.2354 - val_loss: 309621.2188 - val_mean_absolute_error: 370.4362
# Epoch 20/200
# 55/55 [==============================] - 2s 28ms/step - loss: 228387.4531 - mean_absolute_error: 326.9471 - val_loss: 309196.2500 - val_mean_absolute_error: 370.1489
# Epoch 21/200
# 55/55 [==============================] - 2s 27ms/step - loss: 228012.3750 - mean_absolute_error: 326.6598 - val_loss: 308770.2188 - val_mean_absolute_error: 369.8626
# Epoch 22/200
# 55/55 [==============================] - 2s 28ms/step - loss: 227638.2188 - mean_absolute_error: 326.3725 - val_loss: 308346.8125 - val_mean_absolute_error: 369.5744
# Epoch 23/200
# 55/55 [==============================] - 2s 29ms/step - loss: 227264.6406 - mean_absolute_error: 326.0845 - val_loss: 307923.9688 - val_mean_absolute_error: 369.2858
# Epoch 24/200
# 55/55 [==============================] - 2s 28ms/step - loss: 226892.3125 - mean_absolute_error: 325.7971 - val_loss: 307501.5000 - val_mean_absolute_error: 368.9990
# Epoch 25/200
# 55/55 [==============================] - 2s 27ms/step - loss: 226520.0781 - mean_absolute_error: 325.5119 - val_loss: 307080.2188 - val_mean_absolute_error: 368.7131
# Epoch 26/200
# 55/55 [==============================] - 2s 29ms/step - loss: 226148.6094 - mean_absolute_error: 325.2256 - val_loss: 306658.6250 - val_mean_absolute_error: 368.4274
# Epoch 27/200
# 55/55 [==============================] - 2s 28ms/step - loss: 225778.7656 - mean_absolute_error: 324.9384 - val_loss: 306240.5000 - val_mean_absolute_error: 368.1408
# Epoch 28/200
# 55/55 [==============================] - 2s 29ms/step - loss: 225408.6094 - mean_absolute_error: 324.6538 - val_loss: 305819.2188 - val_mean_absolute_error: 367.8561
# Epoch 29/200
# 55/55 [==============================] - 2s 27ms/step - loss: 225039.3750 - mean_absolute_error: 324.3687 - val_loss: 305401.3125 - val_mean_absolute_error: 367.5692
# Epoch 30/200
# 55/55 [==============================] - 2s 28ms/step - loss: 224670.2812 - mean_absolute_error: 324.0823 - val_loss: 304982.7500 - val_mean_absolute_error: 367.2845
# Epoch 31/200
# 55/55 [==============================] - 1s 26ms/step - loss: 224302.4375 - mean_absolute_error: 323.7974 - val_loss: 304565.1250 - val_mean_absolute_error: 366.9989
# Epoch 32/200
# 55/55 [==============================] - 1s 26ms/step - loss: 223934.9844 - mean_absolute_error: 323.5103 - val_loss: 304148.3125 - val_mean_absolute_error: 366.7141
# Epoch 33/200
# 55/55 [==============================] - 2s 27ms/step - loss: 223567.5625 - mean_absolute_error: 323.2266 - val_loss: 303732.0000 - val_mean_absolute_error: 366.4293
# Epoch 34/200
# 55/55 [==============================] - 2s 27ms/step - loss: 223200.6406 - mean_absolute_error: 322.9425 - val_loss: 303315.2188 - val_mean_absolute_error: 366.1462
# Epoch 35/200
# 55/55 [==============================] - 1s 27ms/step - loss: 222833.9844 - mean_absolute_error: 322.6592 - val_loss: 302899.5625 - val_mean_absolute_error: 365.8613
# Epoch 36/200
# 55/55 [==============================] - 1s 26ms/step - loss: 222468.7188 - mean_absolute_error: 322.3745 - val_loss: 302484.4688 - val_mean_absolute_error: 365.5757
# Epoch 37/200
# 55/55 [==============================] - 2s 27ms/step - loss: 222103.3594 - mean_absolute_error: 322.0875 - val_loss: 302070.2188 - val_mean_absolute_error: 365.2900
# Epoch 38/200
# 55/55 [==============================] - 2s 29ms/step - loss: 221738.7969 - mean_absolute_error: 321.8022 - val_loss: 301656.5000 - val_mean_absolute_error: 365.0072
# Epoch 39/200
# 55/55 [==============================] - 2s 28ms/step - loss: 221374.2500 - mean_absolute_error: 321.5190 - val_loss: 301243.0625 - val_mean_absolute_error: 364.7230
# Epoch 40/200
# 55/55 [==============================] - 2s 29ms/step - loss: 221010.1562 - mean_absolute_error: 321.2362 - val_loss: 300828.6875 - val_mean_absolute_error: 364.4388
# Epoch 41/200
# 55/55 [==============================] - 2s 28ms/step - loss: 220646.0312 - mean_absolute_error: 320.9528 - val_loss: 300415.9375 - val_mean_absolute_error: 364.1545
# Epoch 42/200
# 55/55 [==============================] - 1s 27ms/step - loss: 220281.9844 - mean_absolute_error: 320.6677 - val_loss: 300002.9375 - val_mean_absolute_error: 363.8708
# Epoch 43/200
# 55/55 [==============================] - 2s 28ms/step - loss: 219919.3594 - mean_absolute_error: 320.3843 - val_loss: 299590.9375 - val_mean_absolute_error: 363.5880
# Epoch 44/200
# 55/55 [==============================] - 2s 28ms/step - loss: 219557.4219 - mean_absolute_error: 320.1004 - val_loss: 299179.2188 - val_mean_absolute_error: 363.3051
# Epoch 45/200
# 55/55 [==============================] - 1s 27ms/step - loss: 219195.2500 - mean_absolute_error: 319.8180 - val_loss: 298767.9375 - val_mean_absolute_error: 363.0210
# Epoch 46/200
# 55/55 [==============================] - 2s 29ms/step - loss: 218834.0625 - mean_absolute_error: 319.5334 - val_loss: 298357.2812 - val_mean_absolute_error: 362.7358
# Epoch 47/200
# 55/55 [==============================] - 2s 27ms/step - loss: 218473.0312 - mean_absolute_error: 319.2498 - val_loss: 297947.3438 - val_mean_absolute_error: 362.4527
# Epoch 48/200
# 55/55 [==============================] - 2s 28ms/step - loss: 218112.6562 - mean_absolute_error: 318.9645 - val_loss: 297538.7812 - val_mean_absolute_error: 362.1687
# Epoch 49/200
# 55/55 [==============================] - 2s 36ms/step - loss: 217752.8281 - mean_absolute_error: 318.6824 - val_loss: 297128.5625 - val_mean_absolute_error: 361.8851
# Epoch 50/200
# 55/55 [==============================] - 2s 28ms/step - loss: 217392.5000 - mean_absolute_error: 318.3983 - val_loss: 296719.5625 - val_mean_absolute_error: 361.6010
# Epoch 51/200
# 55/55 [==============================] - 2s 27ms/step - loss: 217033.4375 - mean_absolute_error: 318.1162 - val_loss: 296311.1875 - val_mean_absolute_error: 361.3183
# Epoch 52/200
# 55/55 [==============================] - 2s 27ms/step - loss: 216674.1406 - mean_absolute_error: 317.8326 - val_loss: 295903.2500 - val_mean_absolute_error: 361.0343
# Epoch 53/200
# 55/55 [==============================] - 2s 29ms/step - loss: 216315.9844 - mean_absolute_error: 317.5484 - val_loss: 295495.4375 - val_mean_absolute_error: 360.7519
# Epoch 54/200
# 55/55 [==============================] - 2s 30ms/step - loss: 215958.0469 - mean_absolute_error: 317.2658 - val_loss: 295088.6562 - val_mean_absolute_error: 360.4701
# Epoch 55/200
# 55/55 [==============================] - 2s 29ms/step - loss: 215600.5781 - mean_absolute_error: 316.9833 - val_loss: 294681.5938 - val_mean_absolute_error: 360.1864
# Epoch 56/200
# 55/55 [==============================] - 1s 27ms/step - loss: 215242.5938 - mean_absolute_error: 316.6997 - val_loss: 294275.9375 - val_mean_absolute_error: 359.9036
# Epoch 57/200
# 55/55 [==============================] - 3s 45ms/step - loss: 214885.5625 - mean_absolute_error: 316.4179 - val_loss: 293868.0625 - val_mean_absolute_error: 359.6218
# Epoch 58/200
# 55/55 [==============================] - 2s 29ms/step - loss: 214528.3438 - mean_absolute_error: 316.1346 - val_loss: 293462.3750 - val_mean_absolute_error: 359.3399
# Epoch 59/200
# 55/55 [==============================] - 1s 26ms/step - loss: 214172.3750 - mean_absolute_error: 315.8510 - val_loss: 293057.5625 - val_mean_absolute_error: 359.0551
# Epoch 60/200
# 55/55 [==============================] - 2s 27ms/step - loss: 213817.2188 - mean_absolute_error: 315.5677 - val_loss: 292653.3125 - val_mean_absolute_error: 358.7728
# Epoch 61/200
# 55/55 [==============================] - 1s 27ms/step - loss: 213462.5625 - mean_absolute_error: 315.2856 - val_loss: 292249.0625 - val_mean_absolute_error: 358.4891
# Epoch 62/200
# 55/55 [==============================] - 2s 27ms/step - loss: 213107.8906 - mean_absolute_error: 315.0029 - val_loss: 291846.5312 - val_mean_absolute_error: 358.2078
# Epoch 63/200
# 55/55 [==============================] - 2s 28ms/step - loss: 212753.0625 - mean_absolute_error: 314.7216 - val_loss: 291441.6250 - val_mean_absolute_error: 357.9255
# Epoch 64/200
# 55/55 [==============================] - 2s 30ms/step - loss: 212398.4688 - mean_absolute_error: 314.4396 - val_loss: 291037.3750 - val_mean_absolute_error: 357.6425
# Epoch 65/200
# 55/55 [==============================] - 2s 27ms/step - loss: 212044.5156 - mean_absolute_error: 314.1555 - val_loss: 290634.7500 - val_mean_absolute_error: 357.3582
# Epoch 66/200
# 55/55 [==============================] - 2s 29ms/step - loss: 211690.9844 - mean_absolute_error: 313.8706 - val_loss: 290233.5312 - val_mean_absolute_error: 357.0748
# Epoch 67/200
# 55/55 [==============================] - 2s 27ms/step - loss: 211337.6406 - mean_absolute_error: 313.5904 - val_loss: 289830.4688 - val_mean_absolute_error: 356.7943
# Epoch 68/200
# 55/55 [==============================] - 2s 27ms/step - loss: 210984.5000 - mean_absolute_error: 313.3079 - val_loss: 289427.0000 - val_mean_absolute_error: 356.5121
# Epoch 69/200
# 55/55 [==============================] - 2s 27ms/step - loss: 210631.9375 - mean_absolute_error: 313.0243 - val_loss: 289026.7812 - val_mean_absolute_error: 356.2274
# Epoch 70/200
# 55/55 [==============================] - 2s 27ms/step - loss: 210280.2344 - mean_absolute_error: 312.7408 - val_loss: 288625.8125 - val_mean_absolute_error: 355.9463
# Epoch 71/200
# 55/55 [==============================] - 2s 28ms/step - loss: 209928.4062 - mean_absolute_error: 312.4596 - val_loss: 288224.8750 - val_mean_absolute_error: 355.6633
# Epoch 72/200
# 55/55 [==============================] - 2s 28ms/step - loss: 209576.3281 - mean_absolute_error: 312.1773 - val_loss: 287823.8125 - val_mean_absolute_error: 355.3811
# Epoch 73/200
# 55/55 [==============================] - 2s 29ms/step - loss: 209225.8594 - mean_absolute_error: 311.8959 - val_loss: 287424.5312 - val_mean_absolute_error: 355.0995
# Epoch 74/200
# 55/55 [==============================] - 2s 31ms/step - loss: 208875.0469 - mean_absolute_error: 311.6145 - val_loss: 287024.4688 - val_mean_absolute_error: 354.8173
# Epoch 75/200
# 55/55 [==============================] - 2s 31ms/step - loss: 208524.4531 - mean_absolute_error: 311.3325 - val_loss: 286624.0938 - val_mean_absolute_error: 354.5354
# Epoch 76/200
# 55/55 [==============================] - 2s 32ms/step - loss: 208173.9375 - mean_absolute_error: 311.0500 - val_loss: 286225.1562 - val_mean_absolute_error: 354.2545
# Epoch 77/200
# 55/55 [==============================] - 2s 27ms/step - loss: 207823.9688 - mean_absolute_error: 310.7682 - val_loss: 285826.8438 - val_mean_absolute_error: 353.9722
# Epoch 78/200
# 55/55 [==============================] - 2s 27ms/step - loss: 207475.0625 - mean_absolute_error: 310.4865 - val_loss: 285428.1250 - val_mean_absolute_error: 353.6906
# Epoch 79/200
# 55/55 [==============================] - 1s 26ms/step - loss: 207125.9219 - mean_absolute_error: 310.2026 - val_loss: 285030.0000 - val_mean_absolute_error: 353.4067
# Epoch 80/200
# 55/55 [==============================] - 2s 28ms/step - loss: 206777.2656 - mean_absolute_error: 309.9207 - val_loss: 284633.3125 - val_mean_absolute_error: 353.1249
# Epoch 81/200
# 55/55 [==============================] - 2s 28ms/step - loss: 206429.4688 - mean_absolute_error: 309.6395 - val_loss: 284236.1562 - val_mean_absolute_error: 352.8431
# Epoch 82/200
# 55/55 [==============================] - 2s 29ms/step - loss: 206081.8750 - mean_absolute_error: 309.3572 - val_loss: 283840.0938 - val_mean_absolute_error: 352.5622
# Epoch 83/200
# 55/55 [==============================] - 2s 28ms/step - loss: 205735.2188 - mean_absolute_error: 309.0743 - val_loss: 283443.7812 - val_mean_absolute_error: 352.2790
# Epoch 84/200
# 55/55 [==============================] - 2s 27ms/step - loss: 205388.2656 - mean_absolute_error: 308.7927 - val_loss: 283048.5312 - val_mean_absolute_error: 351.9971
# Epoch 85/200
# 55/55 [==============================] - 1s 27ms/step - loss: 205042.2344 - mean_absolute_error: 308.5100 - val_loss: 282653.5938 - val_mean_absolute_error: 351.7146
# Epoch 86/200
# 55/55 [==============================] - 2s 27ms/step - loss: 204696.1250 - mean_absolute_error: 308.2282 - val_loss: 282258.4062 - val_mean_absolute_error: 351.4340
# Epoch 87/200
# 55/55 [==============================] - 2s 27ms/step - loss: 204350.5312 - mean_absolute_error: 307.9473 - val_loss: 281864.6562 - val_mean_absolute_error: 351.1515
# Epoch 88/200
# 55/55 [==============================] - 2s 28ms/step - loss: 204004.5469 - mean_absolute_error: 307.6663 - val_loss: 281469.1875 - val_mean_absolute_error: 350.8683
# Epoch 89/200
# 55/55 [==============================] - 1s 26ms/step - loss: 203658.9062 - mean_absolute_error: 307.3847 - val_loss: 281074.0000 - val_mean_absolute_error: 350.5873
# Epoch 90/200
# 55/55 [==============================] - 2s 29ms/step - loss: 203314.2188 - mean_absolute_error: 307.1030 - val_loss: 280680.6562 - val_mean_absolute_error: 350.3058
# Epoch 91/200
# 55/55 [==============================] - 2s 29ms/step - loss: 202969.7812 - mean_absolute_error: 306.8196 - val_loss: 280287.1875 - val_mean_absolute_error: 350.0225
# Epoch 92/200
# 55/55 [==============================] - 2s 28ms/step - loss: 202625.5469 - mean_absolute_error: 306.5367 - val_loss: 279894.5000 - val_mean_absolute_error: 349.7413
# Epoch 93/200
# 55/55 [==============================] - 2s 29ms/step - loss: 202281.5156 - mean_absolute_error: 306.2565 - val_loss: 279501.0000 - val_mean_absolute_error: 349.4607
# Epoch 94/200
# 55/55 [==============================] - 2s 27ms/step - loss: 201937.5312 - mean_absolute_error: 305.9749 - val_loss: 279108.6562 - val_mean_absolute_error: 349.1783
# Epoch 95/200
# 55/55 [==============================] - 2s 30ms/step - loss: 201593.7500 - mean_absolute_error: 305.6939 - val_loss: 278715.7188 - val_mean_absolute_error: 348.8977
# Epoch 96/200
# 55/55 [==============================] - 2s 28ms/step - loss: 201250.3750 - mean_absolute_error: 305.4128 - val_loss: 278323.0625 - val_mean_absolute_error: 348.6154
# Epoch 97/200
# 55/55 [==============================] - 2s 28ms/step - loss: 200907.2188 - mean_absolute_error: 305.1306 - val_loss: 277931.0625 - val_mean_absolute_error: 348.3319
# Epoch 98/200
# 55/55 [==============================] - 2s 28ms/step - loss: 200564.9062 - mean_absolute_error: 304.8470 - val_loss: 277540.3438 - val_mean_absolute_error: 348.0508
# Epoch 99/200
# 55/55 [==============================] - 2s 28ms/step - loss: 200222.8750 - mean_absolute_error: 304.5661 - val_loss: 277148.8438 - val_mean_absolute_error: 347.7683
# Epoch 100/200
# 55/55 [==============================] - 2s 28ms/step - loss: 199881.9062 - mean_absolute_error: 304.2843 - val_loss: 276758.4375 - val_mean_absolute_error: 347.4875
# Epoch 101/200
# 55/55 [==============================] - 2s 28ms/step - loss: 199540.4219 - mean_absolute_error: 304.0032 - val_loss: 276367.9062 - val_mean_absolute_error: 347.2055
# Epoch 102/200
# 55/55 [==============================] - 2s 28ms/step - loss: 199199.5469 - mean_absolute_error: 303.7197 - val_loss: 275978.9688 - val_mean_absolute_error: 346.9232
# Epoch 103/200
# 55/55 [==============================] - 2s 29ms/step - loss: 198858.5781 - mean_absolute_error: 303.4389 - val_loss: 275588.5938 - val_mean_absolute_error: 346.6425
# Epoch 104/200
# 55/55 [==============================] - 2s 29ms/step - loss: 198517.2656 - mean_absolute_error: 303.1574 - val_loss: 275198.4062 - val_mean_absolute_error: 346.3622
# Epoch 105/200
# 55/55 [==============================] - 2s 28ms/step - loss: 198176.7188 - mean_absolute_error: 302.8764 - val_loss: 274809.2812 - val_mean_absolute_error: 346.0799
# Epoch 106/200
# 55/55 [==============================] - 2s 30ms/step - loss: 197836.9219 - mean_absolute_error: 302.5945 - val_loss: 274420.6562 - val_mean_absolute_error: 345.7971
# Epoch 107/200
# 55/55 [==============================] - 2s 29ms/step - loss: 197496.8438 - mean_absolute_error: 302.3123 - val_loss: 274031.0625 - val_mean_absolute_error: 345.5163
# Epoch 108/200
# 55/55 [==============================] - 2s 30ms/step - loss: 197157.6562 - mean_absolute_error: 302.0311 - val_loss: 273642.9688 - val_mean_absolute_error: 345.2338
# Epoch 109/200
# 55/55 [==============================] - 2s 28ms/step - loss: 196818.6562 - mean_absolute_error: 301.7491 - val_loss: 273255.0938 - val_mean_absolute_error: 344.9529
# Epoch 110/200
# 55/55 [==============================] - 2s 28ms/step - loss: 196481.3438 - mean_absolute_error: 301.4663 - val_loss: 272869.8438 - val_mean_absolute_error: 344.6707
# Epoch 111/200
# 55/55 [==============================] - 1s 27ms/step - loss: 196143.7344 - mean_absolute_error: 301.1852 - val_loss: 272483.5000 - val_mean_absolute_error: 344.3905
# Epoch 112/200
# 55/55 [==============================] - 2s 28ms/step - loss: 195805.8281 - mean_absolute_error: 300.9047 - val_loss: 272095.7812 - val_mean_absolute_error: 344.1103
# Epoch 113/200
# 55/55 [==============================] - 2s 28ms/step - loss: 195469.1094 - mean_absolute_error: 300.6230 - val_loss: 271710.2188 - val_mean_absolute_error: 343.8283
# Epoch 114/200
# 55/55 [==============================] - 2s 28ms/step - loss: 195132.4062 - mean_absolute_error: 300.3399 - val_loss: 271324.8125 - val_mean_absolute_error: 343.5456
# Epoch 115/200
# 55/55 [==============================] - 2s 27ms/step - loss: 194795.9375 - mean_absolute_error: 300.0594 - val_loss: 270938.6562 - val_mean_absolute_error: 343.2650
# Epoch 116/200
# 55/55 [==============================] - 1s 27ms/step - loss: 194459.0938 - mean_absolute_error: 299.7775 - val_loss: 270554.3125 - val_mean_absolute_error: 342.9822
# Epoch 117/200
# 55/55 [==============================] - 2s 27ms/step - loss: 194123.3125 - mean_absolute_error: 299.4977 - val_loss: 270168.6875 - val_mean_absolute_error: 342.7013
# Epoch 118/200
# 55/55 [==============================] - 2s 27ms/step - loss: 193787.5000 - mean_absolute_error: 299.2155 - val_loss: 269785.1250 - val_mean_absolute_error: 342.4202
# Epoch 119/200
# 55/55 [==============================] - 1s 27ms/step - loss: 193452.0938 - mean_absolute_error: 298.9346 - val_loss: 269399.4688 - val_mean_absolute_error: 342.1391
# Epoch 120/200
# 55/55 [==============================] - 2s 30ms/step - loss: 193116.4219 - mean_absolute_error: 298.6544 - val_loss: 269016.0625 - val_mean_absolute_error: 341.8562
# Epoch 121/200
# 55/55 [==============================] - 2s 29ms/step - loss: 192781.8594 - mean_absolute_error: 298.3720 - val_loss: 268631.6875 - val_mean_absolute_error: 341.5760
# Epoch 122/200
# 55/55 [==============================] - 2s 29ms/step - loss: 192447.2500 - mean_absolute_error: 298.0906 - val_loss: 268249.2500 - val_mean_absolute_error: 341.2945
# Epoch 123/200
# 55/55 [==============================] - 2s 29ms/step - loss: 192113.0312 - mean_absolute_error: 297.8093 - val_loss: 267865.4375 - val_mean_absolute_error: 341.0124
# Epoch 124/200
# 55/55 [==============================] - 2s 28ms/step - loss: 191779.1875 - mean_absolute_error: 297.5282 - val_loss: 267483.2812 - val_mean_absolute_error: 340.7316
# Epoch 125/200
# 55/55 [==============================] - 2s 28ms/step - loss: 191445.5781 - mean_absolute_error: 297.2458 - val_loss: 267099.3438 - val_mean_absolute_error: 340.4500
# Epoch 126/200
# 55/55 [==============================] - 2s 28ms/step - loss: 191112.2656 - mean_absolute_error: 296.9635 - val_loss: 266719.0625 - val_mean_absolute_error: 340.1678
# Epoch 127/200
# 55/55 [==============================] - 2s 28ms/step - loss: 190779.9844 - mean_absolute_error: 296.6835 - val_loss: 266337.3438 - val_mean_absolute_error: 339.8885
# Epoch 128/200
# 55/55 [==============================] - 2s 27ms/step - loss: 190447.2969 - mean_absolute_error: 296.4023 - val_loss: 265955.7500 - val_mean_absolute_error: 339.6069
# Epoch 129/200
# 55/55 [==============================] - 2s 28ms/step - loss: 190115.2031 - mean_absolute_error: 296.1215 - val_loss: 265575.4688 - val_mean_absolute_error: 339.3266
# Epoch 130/200
# 55/55 [==============================] - 2s 28ms/step - loss: 189783.8906 - mean_absolute_error: 295.8398 - val_loss: 265194.6875 - val_mean_absolute_error: 339.0438
# Epoch 131/200
# 55/55 [==============================] - 2s 28ms/step - loss: 189451.7031 - mean_absolute_error: 295.5576 - val_loss: 264813.4062 - val_mean_absolute_error: 338.7617
# Epoch 132/200
# 55/55 [==============================] - 2s 28ms/step - loss: 189120.7188 - mean_absolute_error: 295.2766 - val_loss: 264433.0000 - val_mean_absolute_error: 338.4813
# Epoch 133/200
# 55/55 [==============================] - 2s 29ms/step - loss: 188790.4688 - mean_absolute_error: 294.9943 - val_loss: 264054.6562 - val_mean_absolute_error: 338.1985
# Epoch 134/200
# 55/55 [==============================] - 2s 29ms/step - loss: 188460.0312 - mean_absolute_error: 294.7144 - val_loss: 263675.4062 - val_mean_absolute_error: 337.9174
# Epoch 135/200
# 55/55 [==============================] - 2s 29ms/step - loss: 188129.9062 - mean_absolute_error: 294.4325 - val_loss: 263297.0312 - val_mean_absolute_error: 337.6376
# Epoch 136/200
# 55/55 [==============================] - 2s 29ms/step - loss: 187800.9844 - mean_absolute_error: 294.1512 - val_loss: 262918.8125 - val_mean_absolute_error: 337.3555
# Epoch 137/200
# 55/55 [==============================] - 2s 29ms/step - loss: 187471.2031 - mean_absolute_error: 293.8704 - val_loss: 262540.5625 - val_mean_absolute_error: 337.0743
# Epoch 138/200
# 55/55 [==============================] - 2s 28ms/step - loss: 187141.5781 - mean_absolute_error: 293.5893 - val_loss: 262161.2188 - val_mean_absolute_error: 336.7926
# Epoch 139/200
# 55/55 [==============================] - 2s 28ms/step - loss: 186812.3125 - mean_absolute_error: 293.3069 - val_loss: 261783.9688 - val_mean_absolute_error: 336.5111
# Epoch 140/200
# 55/55 [==============================] - 2s 28ms/step - loss: 186483.9062 - mean_absolute_error: 293.0268 - val_loss: 261405.8906 - val_mean_absolute_error: 336.2288
# Epoch 141/200
# 55/55 [==============================] - 2s 28ms/step - loss: 186155.0000 - mean_absolute_error: 292.7441 - val_loss: 261027.9688 - val_mean_absolute_error: 335.9486
# Epoch 142/200
# 55/55 [==============================] - 2s 27ms/step - loss: 185826.4688 - mean_absolute_error: 292.4623 - val_loss: 260650.5156 - val_mean_absolute_error: 335.6674
# Epoch 143/200
# 55/55 [==============================] - 2s 29ms/step - loss: 185499.4219 - mean_absolute_error: 292.1822 - val_loss: 260275.5938 - val_mean_absolute_error: 335.3876
# Epoch 144/200
# 55/55 [==============================] - 2s 28ms/step - loss: 185172.4062 - mean_absolute_error: 291.9012 - val_loss: 259898.7500 - val_mean_absolute_error: 335.1054
# Epoch 145/200
# 55/55 [==============================] - 2s 30ms/step - loss: 184845.4062 - mean_absolute_error: 291.6194 - val_loss: 259523.9688 - val_mean_absolute_error: 334.8246
# Epoch 146/200
# 55/55 [==============================] - 2s 28ms/step - loss: 184519.7969 - mean_absolute_error: 291.3379 - val_loss: 259149.1250 - val_mean_absolute_error: 334.5426
# Epoch 147/200
# 55/55 [==============================] - 2s 30ms/step - loss: 184193.0938 - mean_absolute_error: 291.0567 - val_loss: 258773.5625 - val_mean_absolute_error: 334.2607
# Epoch 148/200
# 55/55 [==============================] - 2s 27ms/step - loss: 183867.9219 - mean_absolute_error: 290.7749 - val_loss: 258400.0000 - val_mean_absolute_error: 333.9804
# Epoch 149/200
# 55/55 [==============================] - 2s 29ms/step - loss: 183542.7031 - mean_absolute_error: 290.4955 - val_loss: 258025.3281 - val_mean_absolute_error: 333.6992
# Epoch 150/200
# 55/55 [==============================] - 2s 29ms/step - loss: 183217.7656 - mean_absolute_error: 290.2151 - val_loss: 257651.4375 - val_mean_absolute_error: 333.4190
# Epoch 151/200
# 55/55 [==============================] - 2s 28ms/step - loss: 182892.7031 - mean_absolute_error: 289.9340 - val_loss: 257278.4688 - val_mean_absolute_error: 333.1378
# Epoch 152/200
# 55/55 [==============================] - 2s 29ms/step - loss: 182569.6094 - mean_absolute_error: 289.6523 - val_loss: 256906.5938 - val_mean_absolute_error: 332.8565
# Epoch 153/200
# 55/55 [==============================] - 2s 27ms/step - loss: 182246.2656 - mean_absolute_error: 289.3702 - val_loss: 256534.8750 - val_mean_absolute_error: 332.5757
# Epoch 154/200
# 55/55 [==============================] - 2s 29ms/step - loss: 181923.0625 - mean_absolute_error: 289.0908 - val_loss: 256162.4375 - val_mean_absolute_error: 332.2968
# Epoch 155/200
# 55/55 [==============================] - 2s 30ms/step - loss: 181599.2656 - mean_absolute_error: 288.8107 - val_loss: 255789.2344 - val_mean_absolute_error: 332.0168
# Epoch 156/200
# 55/55 [==============================] - 2s 28ms/step - loss: 181275.6875 - mean_absolute_error: 288.5303 - val_loss: 255417.3594 - val_mean_absolute_error: 331.7347
# Epoch 157/200
# 55/55 [==============================] - 2s 29ms/step - loss: 180952.2344 - mean_absolute_error: 288.2488 - val_loss: 255044.8906 - val_mean_absolute_error: 331.4548
# Epoch 158/200
# 55/55 [==============================] - 2s 27ms/step - loss: 180629.1875 - mean_absolute_error: 287.9670 - val_loss: 254673.3594 - val_mean_absolute_error: 331.1733
# Epoch 159/200
# 55/55 [==============================] - 2s 28ms/step - loss: 180307.2500 - mean_absolute_error: 287.6867 - val_loss: 254301.9531 - val_mean_absolute_error: 330.8929
# Epoch 160/200
# 55/55 [==============================] - 2s 28ms/step - loss: 179985.6250 - mean_absolute_error: 287.4042 - val_loss: 253932.0000 - val_mean_absolute_error: 330.6111
# Epoch 161/200
# 55/55 [==============================] - 2s 29ms/step - loss: 179663.8906 - mean_absolute_error: 287.1239 - val_loss: 253561.7188 - val_mean_absolute_error: 330.3302
# Epoch 162/200
# 55/55 [==============================] - 2s 29ms/step - loss: 179343.3750 - mean_absolute_error: 286.8434 - val_loss: 253192.8281 - val_mean_absolute_error: 330.0485
# Epoch 163/200
# 55/55 [==============================] - 2s 28ms/step - loss: 179022.3438 - mean_absolute_error: 286.5628 - val_loss: 252823.1250 - val_mean_absolute_error: 329.7689
# Epoch 164/200
# 55/55 [==============================] - 2s 27ms/step - loss: 178702.0469 - mean_absolute_error: 286.2827 - val_loss: 252453.2500 - val_mean_absolute_error: 329.4882
# Epoch 165/200
# 55/55 [==============================] - 1s 27ms/step - loss: 178382.3281 - mean_absolute_error: 286.0018 - val_loss: 252085.4062 - val_mean_absolute_error: 329.2067
# Epoch 166/200
# 55/55 [==============================] - 2s 29ms/step - loss: 178062.1562 - mean_absolute_error: 285.7198 - val_loss: 251715.8906 - val_mean_absolute_error: 328.9255
# Epoch 167/200
# 55/55 [==============================] - 2s 27ms/step - loss: 177742.4844 - mean_absolute_error: 285.4388 - val_loss: 251347.8281 - val_mean_absolute_error: 328.6440
# Epoch 168/200
# 55/55 [==============================] - 2s 29ms/step - loss: 177423.6094 - mean_absolute_error: 285.1576 - val_loss: 250980.4062 - val_mean_absolute_error: 328.3629
# Epoch 169/200
# 55/55 [==============================] - 2s 28ms/step - loss: 177105.1875 - mean_absolute_error: 284.8765 - val_loss: 250612.4062 - val_mean_absolute_error: 328.0816
# Epoch 170/200
# 55/55 [==============================] - 2s 28ms/step - loss: 176786.9531 - mean_absolute_error: 284.5970 - val_loss: 250246.2500 - val_mean_absolute_error: 327.8021
# Epoch 171/200
# 55/55 [==============================] - 1s 27ms/step - loss: 176469.3125 - mean_absolute_error: 284.3157 - val_loss: 249878.9531 - val_mean_absolute_error: 327.5204
# Epoch 172/200
# 55/55 [==============================] - 2s 28ms/step - loss: 176151.0938 - mean_absolute_error: 284.0354 - val_loss: 249512.1719 - val_mean_absolute_error: 327.2393
# Epoch 173/200
# 55/55 [==============================] - 2s 27ms/step - loss: 175833.1875 - mean_absolute_error: 283.7553 - val_loss: 249146.4375 - val_mean_absolute_error: 326.9592
# Epoch 174/200
# 55/55 [==============================] - 1s 27ms/step - loss: 175516.3750 - mean_absolute_error: 283.4733 - val_loss: 248779.7188 - val_mean_absolute_error: 326.6774
# Epoch 175/200
# 55/55 [==============================] - 2s 28ms/step - loss: 175200.2188 - mean_absolute_error: 283.1922 - val_loss: 248416.9531 - val_mean_absolute_error: 326.3972
# Epoch 176/200
# 55/55 [==============================] - 2s 28ms/step - loss: 174884.1250 - mean_absolute_error: 282.9129 - val_loss: 248050.3594 - val_mean_absolute_error: 326.1182
# Epoch 177/200
# 55/55 [==============================] - 2s 28ms/step - loss: 174567.5625 - mean_absolute_error: 282.6325 - val_loss: 247685.6719 - val_mean_absolute_error: 325.8383
# Epoch 178/200
# 55/55 [==============================] - 2s 29ms/step - loss: 174251.7188 - mean_absolute_error: 282.3521 - val_loss: 247320.0781 - val_mean_absolute_error: 325.5560
# Epoch 179/200
# 55/55 [==============================] - 2s 29ms/step - loss: 173936.3281 - mean_absolute_error: 282.0721 - val_loss: 246957.0781 - val_mean_absolute_error: 325.2764
# Epoch 180/200
# 55/55 [==============================] - 2s 28ms/step - loss: 173620.8594 - mean_absolute_error: 281.7915 - val_loss: 246591.9688 - val_mean_absolute_error: 324.9975
# Epoch 181/200
# 55/55 [==============================] - 2s 30ms/step - loss: 173305.9219 - mean_absolute_error: 281.5104 - val_loss: 246228.3906 - val_mean_absolute_error: 324.7146
# Epoch 182/200
# 55/55 [==============================] - 2s 31ms/step - loss: 172991.2656 - mean_absolute_error: 281.2288 - val_loss: 245864.8906 - val_mean_absolute_error: 324.4347
# Epoch 183/200
# 55/55 [==============================] - 2s 30ms/step - loss: 172676.8438 - mean_absolute_error: 280.9488 - val_loss: 245501.8438 - val_mean_absolute_error: 324.1532
# Epoch 184/200
# 55/55 [==============================] - 2s 29ms/step - loss: 172362.8125 - mean_absolute_error: 280.6684 - val_loss: 245139.2812 - val_mean_absolute_error: 323.8730
# Epoch 185/200
# 55/55 [==============================] - 2s 29ms/step - loss: 172049.3438 - mean_absolute_error: 280.3871 - val_loss: 244777.3594 - val_mean_absolute_error: 323.5919
# Epoch 186/200
# 55/55 [==============================] - 2s 28ms/step - loss: 171735.5781 - mean_absolute_error: 280.1060 - val_loss: 244414.7188 - val_mean_absolute_error: 323.3123
# Epoch 187/200
# 55/55 [==============================] - 2s 28ms/step - loss: 171422.7031 - mean_absolute_error: 279.8265 - val_loss: 244052.0469 - val_mean_absolute_error: 323.0303
# Epoch 188/200
# 55/55 [==============================] - 2s 28ms/step - loss: 171110.9531 - mean_absolute_error: 279.5448 - val_loss: 243692.4062 - val_mean_absolute_error: 322.7498
# Epoch 189/200
# 55/55 [==============================] - 2s 28ms/step - loss: 170798.8750 - mean_absolute_error: 279.2634 - val_loss: 243332.7500 - val_mean_absolute_error: 322.4690
# Epoch 190/200
# 55/55 [==============================] - 2s 28ms/step - loss: 170487.1406 - mean_absolute_error: 278.9824 - val_loss: 242972.0000 - val_mean_absolute_error: 322.1884
# Epoch 191/200
# 55/55 [==============================] - 2s 29ms/step - loss: 170175.2656 - mean_absolute_error: 278.7026 - val_loss: 242610.8438 - val_mean_absolute_error: 321.9080
# Epoch 192/200
# 55/55 [==============================] - 2s 30ms/step - loss: 169863.9062 - mean_absolute_error: 278.4226 - val_loss: 242251.1562 - val_mean_absolute_error: 321.6273
# Epoch 193/200
# 55/55 [==============================] - 2s 28ms/step - loss: 169553.4219 - mean_absolute_error: 278.1420 - val_loss: 241892.0000 - val_mean_absolute_error: 321.3468
# Epoch 194/200
# 55/55 [==============================] - 2s 28ms/step - loss: 169242.8906 - mean_absolute_error: 277.8618 - val_loss: 241532.5938 - val_mean_absolute_error: 321.0668
# Epoch 195/200
# 55/55 [==============================] - 2s 28ms/step - loss: 168932.0938 - mean_absolute_error: 277.5819 - val_loss: 241172.9531 - val_mean_absolute_error: 320.7882
# Epoch 196/200
# 55/55 [==============================] - 2s 29ms/step - loss: 168622.2969 - mean_absolute_error: 277.3001 - val_loss: 240815.1250 - val_mean_absolute_error: 320.5063
# Epoch 197/200
# 55/55 [==============================] - 2s 28ms/step - loss: 168312.2969 - mean_absolute_error: 277.0202 - val_loss: 240456.1562 - val_mean_absolute_error: 320.2269
# Epoch 198/200
# 55/55 [==============================] - 2s 28ms/step - loss: 168003.0156 - mean_absolute_error: 276.7406 - val_loss: 240097.0312 - val_mean_absolute_error: 319.9465
# Epoch 199/200
# 55/55 [==============================] - 2s 28ms/step - loss: 167693.5156 - mean_absolute_error: 276.4606 - val_loss: 239739.3281 - val_mean_absolute_error: 319.6647
# Epoch 200/200
# 55/55 [==============================] - 2s 28ms/step - loss: 167384.9062 - mean_absolute_error: 276.1805 - val_loss: 239381.9688 - val_mean_absolute_error: 319.3848

# %%
multi_window.co2_plot(co2_multi_lstm_model)

# %%
multi_window.changepeople_plot(co2_multi_lstm_model)

# %%
co2_multi_lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 32)                4480
#
#  dense (Dense)               (None, 48)                1584
#
#  reshape (Reshape)           (None, 24, 2)             0
#
# =================================================================
# Total params: 6,064
# Trainable params: 6,064
# Non-trainable params: 0
# _________________________________________________________________

# %%
# co2_multi_lstm_model.evaluate(multi_window.test)
co2_multi_lstm_model.evaluate(multi_window.val)
# Out:
# 10/10 [==============================] - 0s 7ms/step - loss: 239381.9688 - mean_absolute_error: 319.3848
# [239381.96875, 319.3847961425781]

# %%
print('_________________________________________________________________')
print('Model evaluate')
print('=================================================================')
# print('Loss: ', co2_multi_performance['LSTM'][0])
# print('MAE(Mean Absolute Error): ', co2_multi_performance['LSTM'][1])

print('Loss: ', co2_multi_val_performance['LSTM'][0])
print('MAE(Mean Absolute Error): ', co2_multi_val_performance['LSTM'][1])
print('=================================================================')
# Out:
# _________________________________________________________________
# Model evaluate
# =================================================================
# Loss:  239381.953125
# MAE(Mean Absolute Error):  319.38482666015625
# =================================================================

# %%
# 6 훈련 과정 시각화 (MAE)
plt.plot(co2_history.history['mean_absolute_error'])
plt.plot(co2_history.history['val_mean_absolute_error'])
plt.title('Model MAE(mean absolute error)')
plt.xlabel('Epoch')
plt.ylabel('mean_absolute_error')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# 7 훈련 과정 시각화 (손실)
plt.plot(co2_history.history['loss'])
plt.plot(co2_history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# # 모델 저장
# co2_multi_lstm_model.save('co2_multi_lstm_model.h5')

# %% [markdown]
# 아래는 필요없는 코드

# %%
changepeople_multi_lstm_model = tf.keras.Sequential([
    tf.keras.layers.LSTM(128, return_sequences=False),
    tf.keras.layers.Dense(OUT_STEPS*num_features,
                          kernel_initializer=tf.initializers.zeros),
    tf.keras.layers.Reshape([OUT_STEPS, num_features])
])

changepeople_history = compile_and_fit(changepeople_multi_lstm_model, multi_window)

changepeople_multi_val_performance = {}
changepeople_multi_performance = {}
changepeople_multi_val_performance['LSTM'] = changepeople_multi_lstm_model.evaluate(multi_window.val)
changepeople_multi_performance['LSTM'] = changepeople_multi_lstm_model.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/200
# 55/55 [==============================] - 5s 53ms/step - loss: 235189.7031 - mean_absolute_error: 331.9543 - val_loss: 315930.0625 - val_mean_absolute_error: 374.6513
# Epoch 2/200
# 55/55 [==============================] - 2s 44ms/step - loss: 233054.4688 - mean_absolute_error: 330.5015 - val_loss: 313355.5000 - val_mean_absolute_error: 372.9620
# Epoch 3/200
# 55/55 [==============================] - 3s 46ms/step - loss: 230695.3594 - mean_absolute_error: 328.7199 - val_loss: 310603.0938 - val_mean_absolute_error: 371.1022
# Epoch 4/200
# 55/55 [==============================] - 2s 44ms/step - loss: 228278.2656 - mean_absolute_error: 326.8676 - val_loss: 307895.9375 - val_mean_absolute_error: 369.2643
# Epoch 5/200
# 55/55 [==============================] - 2s 45ms/step - loss: 225829.0938 - mean_absolute_error: 324.9803 - val_loss: 305092.7188 - val_mean_absolute_error: 367.3617
# Epoch 6/200
# 55/55 [==============================] - 3s 45ms/step - loss: 223357.1875 - mean_absolute_error: 323.0744 - val_loss: 302207.8438 - val_mean_absolute_error: 365.3900
# Epoch 7/200
# 55/55 [==============================] - 2s 43ms/step - loss: 220816.0000 - mean_absolute_error: 321.0880 - val_loss: 299366.8438 - val_mean_absolute_error: 363.4300
# Epoch 8/200
# 55/55 [==============================] - 2s 43ms/step - loss: 218346.4219 - mean_absolute_error: 319.1563 - val_loss: 296643.2188 - val_mean_absolute_error: 361.5433
# Epoch 9/200
# 55/55 [==============================] - 2s 44ms/step - loss: 216016.3750 - mean_absolute_error: 317.3109 - val_loss: 294018.2500 - val_mean_absolute_error: 359.7329
# Epoch 10/200
# 55/55 [==============================] - 2s 44ms/step - loss: 213735.3750 - mean_absolute_error: 315.5060 - val_loss: 291445.5625 - val_mean_absolute_error: 357.9282
# Epoch 11/200
# 55/55 [==============================] - 2s 44ms/step - loss: 211490.4375 - mean_absolute_error: 313.7167 - val_loss: 288911.7500 - val_mean_absolute_error: 356.1512
# Epoch 12/200
# 55/55 [==============================] - 2s 43ms/step - loss: 209280.0156 - mean_absolute_error: 311.9501 - val_loss: 286364.1562 - val_mean_absolute_error: 354.3495
# Epoch 13/200
# 55/55 [==============================] - 2s 45ms/step - loss: 206998.1875 - mean_absolute_error: 310.0992 - val_loss: 283754.3125 - val_mean_absolute_error: 352.5031
# Epoch 14/200
# 55/55 [==============================] - 2s 45ms/step - loss: 204743.2656 - mean_absolute_error: 308.2754 - val_loss: 281215.7500 - val_mean_absolute_error: 350.6913
# Epoch 15/200
# 55/55 [==============================] - 2s 43ms/step - loss: 202542.5469 - mean_absolute_error: 306.4807 - val_loss: 278723.8125 - val_mean_absolute_error: 348.9095
# Epoch 16/200
# 55/55 [==============================] - 2s 43ms/step - loss: 200266.5625 - mean_absolute_error: 304.6066 - val_loss: 276108.3438 - val_mean_absolute_error: 347.0171
# Epoch 17/200
# 55/55 [==============================] - 2s 43ms/step - loss: 198019.2812 - mean_absolute_error: 302.7477 - val_loss: 273454.9062 - val_mean_absolute_error: 345.0999
# Epoch 18/200
# 55/55 [==============================] - 2s 44ms/step - loss: 195648.3750 - mean_absolute_error: 300.7708 - val_loss: 270812.2188 - val_mean_absolute_error: 343.1682
# Epoch 19/200
# 55/55 [==============================] - 2s 44ms/step - loss: 193372.7500 - mean_absolute_error: 298.8743 - val_loss: 268142.4375 - val_mean_absolute_error: 341.2209
# Epoch 20/200
# 55/55 [==============================] - 2s 43ms/step - loss: 191094.7812 - mean_absolute_error: 296.9523 - val_loss: 265395.5625 - val_mean_absolute_error: 339.1877
# Epoch 21/200
# 55/55 [==============================] - 2s 43ms/step - loss: 188717.9844 - mean_absolute_error: 294.9369 - val_loss: 262876.0938 - val_mean_absolute_error: 337.3272
# Epoch 22/200
# 55/55 [==============================] - 2s 44ms/step - loss: 186545.5469 - mean_absolute_error: 293.0857 - val_loss: 260390.5312 - val_mean_absolute_error: 335.4807
# Epoch 23/200
# 55/55 [==============================] - 2s 44ms/step - loss: 184405.1562 - mean_absolute_error: 291.2360 - val_loss: 257958.5312 - val_mean_absolute_error: 333.6430
# Epoch 24/200
# 55/55 [==============================] - 2s 43ms/step - loss: 182297.7812 - mean_absolute_error: 289.4262 - val_loss: 255539.9688 - val_mean_absolute_error: 331.8178
# Epoch 25/200
# 55/55 [==============================] - 2s 43ms/step - loss: 180212.7969 - mean_absolute_error: 287.6055 - val_loss: 253159.9531 - val_mean_absolute_error: 330.0265
# Epoch 26/200
# 55/55 [==============================] - 2s 44ms/step - loss: 178166.2656 - mean_absolute_error: 285.8111 - val_loss: 250812.4375 - val_mean_absolute_error: 328.2361
# Epoch 27/200
# 55/55 [==============================] - 2s 44ms/step - loss: 176132.9219 - mean_absolute_error: 284.0228 - val_loss: 248480.2344 - val_mean_absolute_error: 326.4478
# Epoch 28/200
# 55/55 [==============================] - 2s 45ms/step - loss: 174124.3281 - mean_absolute_error: 282.2405 - val_loss: 246178.5312 - val_mean_absolute_error: 324.6715
# Epoch 29/200
# 55/55 [==============================] - 2s 45ms/step - loss: 172138.8594 - mean_absolute_error: 280.4665 - val_loss: 243888.3906 - val_mean_absolute_error: 322.9051
# Epoch 30/200
# 55/55 [==============================] - 2s 44ms/step - loss: 170177.2656 - mean_absolute_error: 278.7025 - val_loss: 241638.7969 - val_mean_absolute_error: 321.1472
# Epoch 31/200
# 55/55 [==============================] - 2s 44ms/step - loss: 168232.5156 - mean_absolute_error: 276.9552 - val_loss: 239390.5938 - val_mean_absolute_error: 319.3914
# Epoch 32/200
# 55/55 [==============================] - 2s 44ms/step - loss: 166302.2500 - mean_absolute_error: 275.1946 - val_loss: 237169.6406 - val_mean_absolute_error: 317.6432
# Epoch 33/200
# 55/55 [==============================] - 2s 44ms/step - loss: 164394.1719 - mean_absolute_error: 273.4481 - val_loss: 234961.2500 - val_mean_absolute_error: 315.8982
# Epoch 34/200
# 55/55 [==============================] - 2s 43ms/step - loss: 162501.9062 - mean_absolute_error: 271.7070 - val_loss: 232779.3594 - val_mean_absolute_error: 314.1494
# Epoch 35/200
# 55/55 [==============================] - 2s 43ms/step - loss: 160627.4062 - mean_absolute_error: 269.9691 - val_loss: 230608.2500 - val_mean_absolute_error: 312.4272
# Epoch 36/200
# 55/55 [==============================] - 2s 44ms/step - loss: 158770.2188 - mean_absolute_error: 268.2384 - val_loss: 228458.4688 - val_mean_absolute_error: 310.6862
# Epoch 37/200
# 55/55 [==============================] - 2s 45ms/step - loss: 156930.0469 - mean_absolute_error: 266.5003 - val_loss: 226337.2031 - val_mean_absolute_error: 308.9655
# Epoch 38/200
# 55/55 [==============================] - 2s 44ms/step - loss: 155113.6094 - mean_absolute_error: 264.7938 - val_loss: 224218.3906 - val_mean_absolute_error: 307.2450
# Epoch 39/200
# 55/55 [==============================] - 2s 43ms/step - loss: 153309.9219 - mean_absolute_error: 263.0699 - val_loss: 222125.1719 - val_mean_absolute_error: 305.5295
# Epoch 40/200
# 55/55 [==============================] - 2s 44ms/step - loss: 151516.0312 - mean_absolute_error: 261.3600 - val_loss: 220041.6094 - val_mean_absolute_error: 303.8214
# Epoch 41/200
# 55/55 [==============================] - 2s 45ms/step - loss: 149740.7656 - mean_absolute_error: 259.6451 - val_loss: 217975.7500 - val_mean_absolute_error: 302.1088
# Epoch 42/200
# 55/55 [==============================] - 2s 43ms/step - loss: 147980.5938 - mean_absolute_error: 257.9391 - val_loss: 215931.3594 - val_mean_absolute_error: 300.4068
# Epoch 43/200
# 55/55 [==============================] - 2s 43ms/step - loss: 146237.8281 - mean_absolute_error: 256.2390 - val_loss: 213896.5469 - val_mean_absolute_error: 298.7062
# Epoch 44/200
# 55/55 [==============================] - 2s 44ms/step - loss: 144509.5000 - mean_absolute_error: 254.5372 - val_loss: 211880.1094 - val_mean_absolute_error: 297.0072
# Epoch 45/200
# 55/55 [==============================] - 2s 44ms/step - loss: 142797.6875 - mean_absolute_error: 252.8410 - val_loss: 209880.1250 - val_mean_absolute_error: 295.3207
# Epoch 46/200
# 55/55 [==============================] - 2s 43ms/step - loss: 141101.1719 - mean_absolute_error: 251.1410 - val_loss: 207896.1250 - val_mean_absolute_error: 293.6223
# Epoch 47/200
# 55/55 [==============================] - 2s 44ms/step - loss: 139418.1719 - mean_absolute_error: 249.4612 - val_loss: 205927.5469 - val_mean_absolute_error: 291.9350
# Epoch 48/200
# 55/55 [==============================] - 2s 44ms/step - loss: 137757.3750 - mean_absolute_error: 247.7756 - val_loss: 203988.7500 - val_mean_absolute_error: 290.2649
# Epoch 49/200
# 55/55 [==============================] - 2s 43ms/step - loss: 136105.1875 - mean_absolute_error: 246.1024 - val_loss: 202043.4062 - val_mean_absolute_error: 288.5846
# Epoch 50/200
# 55/55 [==============================] - 2s 45ms/step - loss: 134464.8125 - mean_absolute_error: 244.4197 - val_loss: 200121.4375 - val_mean_absolute_error: 286.9023
# Epoch 51/200
# 55/55 [==============================] - 2s 44ms/step - loss: 132839.9688 - mean_absolute_error: 242.7488 - val_loss: 198215.3125 - val_mean_absolute_error: 285.2314
# Epoch 52/200
# 55/55 [==============================] - 2s 45ms/step - loss: 131229.4219 - mean_absolute_error: 241.0779 - val_loss: 196318.9531 - val_mean_absolute_error: 283.5594
# Epoch 53/200
# 55/55 [==============================] - 2s 45ms/step - loss: 129631.7969 - mean_absolute_error: 239.4051 - val_loss: 194433.6406 - val_mean_absolute_error: 281.8902
# Epoch 54/200
# 55/55 [==============================] - 2s 45ms/step - loss: 128050.4062 - mean_absolute_error: 237.7386 - val_loss: 192570.4062 - val_mean_absolute_error: 280.2273
# Epoch 55/200
# 55/55 [==============================] - 2s 44ms/step - loss: 126485.3672 - mean_absolute_error: 236.0808 - val_loss: 190728.5156 - val_mean_absolute_error: 278.5769
# Epoch 56/200
# 55/55 [==============================] - 2s 45ms/step - loss: 124931.5234 - mean_absolute_error: 234.4201 - val_loss: 188887.7500 - val_mean_absolute_error: 276.9120
# Epoch 57/200
# 55/55 [==============================] - 2s 44ms/step - loss: 123246.1016 - mean_absolute_error: 232.6030 - val_loss: 186678.7344 - val_mean_absolute_error: 274.8967
# Epoch 58/200
# 55/55 [==============================] - 2s 44ms/step - loss: 121527.8125 - mean_absolute_error: 230.7431 - val_loss: 184849.4062 - val_mean_absolute_error: 273.2267
# Epoch 59/200
# 55/55 [==============================] - 2s 45ms/step - loss: 120006.6797 - mean_absolute_error: 229.0741 - val_loss: 183061.8438 - val_mean_absolute_error: 271.5800
# Epoch 60/200
# 55/55 [==============================] - 2s 43ms/step - loss: 118500.0000 - mean_absolute_error: 227.4241 - val_loss: 181263.7500 - val_mean_absolute_error: 269.9166
# Epoch 61/200
# 55/55 [==============================] - 2s 44ms/step - loss: 117004.4297 - mean_absolute_error: 225.7691 - val_loss: 179492.3281 - val_mean_absolute_error: 268.2601
# Epoch 62/200
# 55/55 [==============================] - 3s 46ms/step - loss: 115528.3047 - mean_absolute_error: 224.1208 - val_loss: 177738.3594 - val_mean_absolute_error: 266.6135
# Epoch 63/200
# 55/55 [==============================] - 2s 43ms/step - loss: 114069.5234 - mean_absolute_error: 222.4700 - val_loss: 175994.4844 - val_mean_absolute_error: 264.9730
# Epoch 64/200
# 55/55 [==============================] - 2s 43ms/step - loss: 112620.4297 - mean_absolute_error: 220.8269 - val_loss: 174268.0312 - val_mean_absolute_error: 263.3228
# Epoch 65/200
# 55/55 [==============================] - 3s 45ms/step - loss: 111184.3438 - mean_absolute_error: 219.1878 - val_loss: 172548.8906 - val_mean_absolute_error: 261.6868
# Epoch 66/200
# 55/55 [==============================] - 3s 45ms/step - loss: 109761.8047 - mean_absolute_error: 217.5529 - val_loss: 170853.0469 - val_mean_absolute_error: 260.0583
# Epoch 67/200
# 55/55 [==============================] - 2s 43ms/step - loss: 108354.0469 - mean_absolute_error: 215.9146 - val_loss: 169163.8281 - val_mean_absolute_error: 258.4213
# Epoch 68/200
# 55/55 [==============================] - 2s 43ms/step - loss: 106957.8359 - mean_absolute_error: 214.2807 - val_loss: 167493.0312 - val_mean_absolute_error: 256.7843
# Epoch 69/200
# 55/55 [==============================] - 2s 44ms/step - loss: 105581.0938 - mean_absolute_error: 212.6614 - val_loss: 165847.2344 - val_mean_absolute_error: 255.1720
# Epoch 70/200
# 55/55 [==============================] - 2s 44ms/step - loss: 104212.8047 - mean_absolute_error: 211.0438 - val_loss: 164193.2344 - val_mean_absolute_error: 253.5508
# Epoch 71/200
# 55/55 [==============================] - 2s 43ms/step - loss: 102860.6797 - mean_absolute_error: 209.4190 - val_loss: 162571.6562 - val_mean_absolute_error: 251.9366
# Epoch 72/200
# 55/55 [==============================] - 2s 44ms/step - loss: 101515.1328 - mean_absolute_error: 207.8023 - val_loss: 160944.7188 - val_mean_absolute_error: 250.3073
# Epoch 73/200
# 55/55 [==============================] - 2s 44ms/step - loss: 100183.6250 - mean_absolute_error: 206.1823 - val_loss: 159336.5000 - val_mean_absolute_error: 248.6891
# Epoch 74/200
# 55/55 [==============================] - 2s 45ms/step - loss: 98862.9844 - mean_absolute_error: 204.5662 - val_loss: 157748.0156 - val_mean_absolute_error: 247.0846
# Epoch 75/200
# 55/55 [==============================] - 2s 43ms/step - loss: 97553.2500 - mean_absolute_error: 202.9529 - val_loss: 156160.6250 - val_mean_absolute_error: 245.4664
# Epoch 76/200
# 55/55 [==============================] - 2s 44ms/step - loss: 96259.7500 - mean_absolute_error: 201.3364 - val_loss: 154597.9844 - val_mean_absolute_error: 243.8640
# Epoch 77/200
# 55/55 [==============================] - 2s 45ms/step - loss: 94979.3516 - mean_absolute_error: 199.7379 - val_loss: 153042.4375 - val_mean_absolute_error: 242.2548
# Epoch 78/200
# 55/55 [==============================] - 3s 45ms/step - loss: 93713.2422 - mean_absolute_error: 198.1347 - val_loss: 151498.2969 - val_mean_absolute_error: 240.6525
# Epoch 79/200
# 55/55 [==============================] - 2s 44ms/step - loss: 92454.2266 - mean_absolute_error: 196.5352 - val_loss: 149973.1094 - val_mean_absolute_error: 239.0547
# Epoch 80/200
# 55/55 [==============================] - 2s 45ms/step - loss: 91211.4219 - mean_absolute_error: 194.9392 - val_loss: 148453.7188 - val_mean_absolute_error: 237.4535
# Epoch 81/200
# 55/55 [==============================] - 2s 44ms/step - loss: 89979.4922 - mean_absolute_error: 193.3307 - val_loss: 146954.1406 - val_mean_absolute_error: 235.8609
# Epoch 82/200
# 55/55 [==============================] - 2s 43ms/step - loss: 88757.8359 - mean_absolute_error: 191.7444 - val_loss: 145455.2969 - val_mean_absolute_error: 234.2603
# Epoch 83/200
# 55/55 [==============================] - 2s 43ms/step - loss: 87545.9688 - mean_absolute_error: 190.1434 - val_loss: 143969.8125 - val_mean_absolute_error: 232.6664
# Epoch 84/200
# 55/55 [==============================] - 2s 43ms/step - loss: 86356.2188 - mean_absolute_error: 188.5507 - val_loss: 142516.8750 - val_mean_absolute_error: 231.0872
# Epoch 85/200
# 55/55 [==============================] - 3s 46ms/step - loss: 85172.2891 - mean_absolute_error: 186.9806 - val_loss: 141060.5312 - val_mean_absolute_error: 229.5084
# Epoch 86/200
# 55/55 [==============================] - 2s 44ms/step - loss: 84000.2031 - mean_absolute_error: 185.3915 - val_loss: 139620.1562 - val_mean_absolute_error: 227.9274
# Epoch 87/200
# 55/55 [==============================] - 2s 43ms/step - loss: 82842.0859 - mean_absolute_error: 183.8143 - val_loss: 138190.6719 - val_mean_absolute_error: 226.3426
# Epoch 88/200
# 55/55 [==============================] - 2s 43ms/step - loss: 81699.6484 - mean_absolute_error: 182.2413 - val_loss: 136792.2188 - val_mean_absolute_error: 224.7805
# Epoch 89/200
# 55/55 [==============================] - 2s 44ms/step - loss: 80564.0938 - mean_absolute_error: 180.6753 - val_loss: 135380.7188 - val_mean_absolute_error: 223.2073
# Epoch 90/200
# 55/55 [==============================] - 2s 43ms/step - loss: 79436.5625 - mean_absolute_error: 179.0949 - val_loss: 133989.6719 - val_mean_absolute_error: 221.6344
# Epoch 91/200
# 55/55 [==============================] - 2s 43ms/step - loss: 78321.8984 - mean_absolute_error: 177.5286 - val_loss: 132604.5625 - val_mean_absolute_error: 220.0585
# Epoch 92/200
# 55/55 [==============================] - 2s 44ms/step - loss: 77220.8047 - mean_absolute_error: 175.9568 - val_loss: 131236.9375 - val_mean_absolute_error: 218.4960
# Epoch 93/200
# 55/55 [==============================] - 2s 42ms/step - loss: 76133.7969 - mean_absolute_error: 174.3877 - val_loss: 129882.9141 - val_mean_absolute_error: 216.9297
# Epoch 94/200
# 55/55 [==============================] - 2s 43ms/step - loss: 75055.3438 - mean_absolute_error: 172.8309 - val_loss: 128535.3828 - val_mean_absolute_error: 215.3717
# Epoch 95/200
# 55/55 [==============================] - 2s 42ms/step - loss: 73985.4219 - mean_absolute_error: 171.2637 - val_loss: 127196.6641 - val_mean_absolute_error: 213.8021
# Epoch 96/200
# 55/55 [==============================] - 2s 42ms/step - loss: 72936.9375 - mean_absolute_error: 169.7086 - val_loss: 125892.6797 - val_mean_absolute_error: 212.2657
# Epoch 97/200
# 55/55 [==============================] - 2s 43ms/step - loss: 71897.0234 - mean_absolute_error: 168.1657 - val_loss: 124585.8594 - val_mean_absolute_error: 210.7106
# Epoch 98/200
# 55/55 [==============================] - 2s 43ms/step - loss: 70870.7578 - mean_absolute_error: 166.6196 - val_loss: 123297.8984 - val_mean_absolute_error: 209.1689
# Epoch 99/200
# 55/55 [==============================] - 2s 43ms/step - loss: 69850.1406 - mean_absolute_error: 165.0803 - val_loss: 122010.6250 - val_mean_absolute_error: 207.6155
# Epoch 100/200
# 55/55 [==============================] - 2s 43ms/step - loss: 68839.1953 - mean_absolute_error: 163.5251 - val_loss: 120740.5000 - val_mean_absolute_error: 206.0755
# Epoch 101/200
# 55/55 [==============================] - 2s 43ms/step - loss: 67844.4844 - mean_absolute_error: 161.9794 - val_loss: 119479.3359 - val_mean_absolute_error: 204.5305
# Epoch 102/200
# 55/55 [==============================] - 2s 43ms/step - loss: 66859.9453 - mean_absolute_error: 160.4468 - val_loss: 118234.6953 - val_mean_absolute_error: 203.0002
# Epoch 103/200
# 55/55 [==============================] - 2s 43ms/step - loss: 65887.6875 - mean_absolute_error: 158.9129 - val_loss: 117000.5234 - val_mean_absolute_error: 201.4606
# Epoch 104/200
# 55/55 [==============================] - 2s 43ms/step - loss: 64926.2891 - mean_absolute_error: 157.3791 - val_loss: 115779.0391 - val_mean_absolute_error: 199.9419
# Epoch 105/200
# 55/55 [==============================] - 2s 43ms/step - loss: 63975.7617 - mean_absolute_error: 155.8541 - val_loss: 114569.2656 - val_mean_absolute_error: 198.4085
# Epoch 106/200
# 55/55 [==============================] - 2s 42ms/step - loss: 63033.5703 - mean_absolute_error: 154.3238 - val_loss: 113363.6797 - val_mean_absolute_error: 196.8864
# Epoch 107/200
# 55/55 [==============================] - 2s 44ms/step - loss: 62102.4531 - mean_absolute_error: 152.7980 - val_loss: 112173.9453 - val_mean_absolute_error: 195.3503
# Epoch 108/200
# 55/55 [==============================] - 2s 43ms/step - loss: 61185.4141 - mean_absolute_error: 151.2739 - val_loss: 111003.2344 - val_mean_absolute_error: 193.8523
# Epoch 109/200
# 55/55 [==============================] - 2s 43ms/step - loss: 60280.6680 - mean_absolute_error: 149.7629 - val_loss: 109841.9609 - val_mean_absolute_error: 192.3337
# Epoch 110/200
# 55/55 [==============================] - 2s 43ms/step - loss: 59385.4023 - mean_absolute_error: 148.2515 - val_loss: 108683.2578 - val_mean_absolute_error: 190.8113
# Epoch 111/200
# 55/55 [==============================] - 2s 43ms/step - loss: 58502.0859 - mean_absolute_error: 146.7353 - val_loss: 107539.9219 - val_mean_absolute_error: 189.3006
# Epoch 112/200
# 55/55 [==============================] - 2s 43ms/step - loss: 57627.3008 - mean_absolute_error: 145.2247 - val_loss: 106412.5000 - val_mean_absolute_error: 187.7998
# Epoch 113/200
# 55/55 [==============================] - 2s 44ms/step - loss: 56766.4883 - mean_absolute_error: 143.7294 - val_loss: 105298.0469 - val_mean_absolute_error: 186.3000
# Epoch 114/200
# 55/55 [==============================] - 2s 43ms/step - loss: 55916.7617 - mean_absolute_error: 142.2349 - val_loss: 104194.6641 - val_mean_absolute_error: 184.8061
# Epoch 115/200
# 55/55 [==============================] - 2s 43ms/step - loss: 55078.8203 - mean_absolute_error: 140.7385 - val_loss: 103096.9141 - val_mean_absolute_error: 183.3159
# Epoch 116/200
# 55/55 [==============================] - 2s 42ms/step - loss: 54248.3320 - mean_absolute_error: 139.2390 - val_loss: 102010.3906 - val_mean_absolute_error: 181.8188
# Epoch 117/200
# 55/55 [==============================] - 2s 43ms/step - loss: 53427.6484 - mean_absolute_error: 137.7463 - val_loss: 100937.3359 - val_mean_absolute_error: 180.3227
# Epoch 118/200
# 55/55 [==============================] - 2s 43ms/step - loss: 52620.1133 - mean_absolute_error: 136.2622 - val_loss: 99880.9141 - val_mean_absolute_error: 178.8436
# Epoch 119/200
# 55/55 [==============================] - 2s 43ms/step - loss: 51822.9414 - mean_absolute_error: 134.7803 - val_loss: 98825.1484 - val_mean_absolute_error: 177.3594
# Epoch 120/200
# 55/55 [==============================] - 2s 42ms/step - loss: 51038.1094 - mean_absolute_error: 133.3007 - val_loss: 97795.5000 - val_mean_absolute_error: 175.8912
# Epoch 121/200
# 55/55 [==============================] - 2s 43ms/step - loss: 50272.3516 - mean_absolute_error: 131.8434 - val_loss: 96781.7188 - val_mean_absolute_error: 174.4378
# Epoch 122/200
# 55/55 [==============================] - 2s 45ms/step - loss: 49511.4648 - mean_absolute_error: 130.3745 - val_loss: 95770.7969 - val_mean_absolute_error: 172.9720
# Epoch 123/200
# 55/55 [==============================] - 2s 45ms/step - loss: 48759.9141 - mean_absolute_error: 128.9193 - val_loss: 94765.0000 - val_mean_absolute_error: 171.5085
# Epoch 124/200
# 55/55 [==============================] - 3s 49ms/step - loss: 48020.4922 - mean_absolute_error: 127.4588 - val_loss: 93785.0312 - val_mean_absolute_error: 170.0630
# Epoch 125/200
# 55/55 [==============================] - 3s 50ms/step - loss: 47288.3398 - mean_absolute_error: 126.0079 - val_loss: 92799.9141 - val_mean_absolute_error: 168.6006
# Epoch 126/200
# 55/55 [==============================] - 3s 46ms/step - loss: 46562.8164 - mean_absolute_error: 124.5470 - val_loss: 91828.1641 - val_mean_absolute_error: 167.1427
# Epoch 127/200
# 55/55 [==============================] - 3s 47ms/step - loss: 45851.6680 - mean_absolute_error: 123.0948 - val_loss: 90863.0625 - val_mean_absolute_error: 165.6882
# Epoch 128/200
# 55/55 [==============================] - 3s 47ms/step - loss: 45149.5977 - mean_absolute_error: 121.6488 - val_loss: 89918.4219 - val_mean_absolute_error: 164.2460
# Epoch 129/200
# 55/55 [==============================] - 3s 46ms/step - loss: 44462.7266 - mean_absolute_error: 120.2019 - val_loss: 88988.4141 - val_mean_absolute_error: 162.8135
# Epoch 130/200
# 55/55 [==============================] - 3s 47ms/step - loss: 43782.7031 - mean_absolute_error: 118.7753 - val_loss: 88059.7109 - val_mean_absolute_error: 161.3772
# Epoch 131/200
# 55/55 [==============================] - 3s 46ms/step - loss: 43111.6562 - mean_absolute_error: 117.3383 - val_loss: 87142.7109 - val_mean_absolute_error: 159.9392
# Epoch 132/200
# 55/55 [==============================] - 2s 44ms/step - loss: 42459.1953 - mean_absolute_error: 115.9130 - val_loss: 86254.0859 - val_mean_absolute_error: 158.5268
# Epoch 133/200
# 55/55 [==============================] - 3s 46ms/step - loss: 41814.3594 - mean_absolute_error: 114.5069 - val_loss: 85371.3203 - val_mean_absolute_error: 157.1256
# Epoch 134/200
# 55/55 [==============================] - 2s 45ms/step - loss: 41177.0078 - mean_absolute_error: 113.1002 - val_loss: 84495.4609 - val_mean_absolute_error: 155.7180
# Epoch 135/200
# 55/55 [==============================] - 2s 44ms/step - loss: 40548.3242 - mean_absolute_error: 111.6910 - val_loss: 83624.7344 - val_mean_absolute_error: 154.3091
# Epoch 136/200
# 55/55 [==============================] - 3s 47ms/step - loss: 39928.0234 - mean_absolute_error: 110.2764 - val_loss: 82767.2578 - val_mean_absolute_error: 152.8950
# Epoch 137/200
# 55/55 [==============================] - 2s 44ms/step - loss: 39319.9922 - mean_absolute_error: 108.8662 - val_loss: 81917.2812 - val_mean_absolute_error: 151.4943
# Epoch 138/200
# 55/55 [==============================] - 2s 44ms/step - loss: 38724.0078 - mean_absolute_error: 107.4792 - val_loss: 81081.0469 - val_mean_absolute_error: 150.0995
# Epoch 139/200
# 55/55 [==============================] - 2s 44ms/step - loss: 38132.3125 - mean_absolute_error: 106.1001 - val_loss: 80247.1797 - val_mean_absolute_error: 148.6964
# Epoch 140/200
# 55/55 [==============================] - 2s 45ms/step - loss: 37550.8516 - mean_absolute_error: 104.7955 - val_loss: 79440.0859 - val_mean_absolute_error: 147.3242
# Epoch 141/200
# 55/55 [==============================] - 2s 44ms/step - loss: 36982.0273 - mean_absolute_error: 103.5595 - val_loss: 78625.3281 - val_mean_absolute_error: 145.9249
# Epoch 142/200
# 55/55 [==============================] - 2s 44ms/step - loss: 36427.0938 - mean_absolute_error: 102.3993 - val_loss: 77839.4375 - val_mean_absolute_error: 144.5597
# Epoch 143/200
# 55/55 [==============================] - 2s 45ms/step - loss: 35878.1094 - mean_absolute_error: 101.2914 - val_loss: 77060.4922 - val_mean_absolute_error: 143.2022
# Epoch 144/200
# 55/55 [==============================] - 2s 45ms/step - loss: 35338.7578 - mean_absolute_error: 100.2244 - val_loss: 76290.4141 - val_mean_absolute_error: 141.8373
# Epoch 145/200
# 55/55 [==============================] - 2s 43ms/step - loss: 34809.0586 - mean_absolute_error: 99.1930 - val_loss: 75528.1328 - val_mean_absolute_error: 140.4757
# Epoch 146/200
# 55/55 [==============================] - 2s 43ms/step - loss: 34285.4141 - mean_absolute_error: 98.1770 - val_loss: 74770.7891 - val_mean_absolute_error: 139.1094
# Epoch 147/200
# 55/55 [==============================] - 2s 44ms/step - loss: 33773.9375 - mean_absolute_error: 97.1910 - val_loss: 74028.7188 - val_mean_absolute_error: 137.7682
# Epoch 148/200
# 55/55 [==============================] - 2s 43ms/step - loss: 33271.9453 - mean_absolute_error: 96.2311 - val_loss: 73299.7031 - val_mean_absolute_error: 136.4300
# Epoch 149/200
# 55/55 [==============================] - 2s 43ms/step - loss: 32780.8125 - mean_absolute_error: 95.3190 - val_loss: 72577.5703 - val_mean_absolute_error: 135.0994
# Epoch 150/200
# 55/55 [==============================] - 2s 44ms/step - loss: 32295.6250 - mean_absolute_error: 94.4557 - val_loss: 71867.9375 - val_mean_absolute_error: 133.7808
# Epoch 151/200
# 55/55 [==============================] - 2s 43ms/step - loss: 31820.2832 - mean_absolute_error: 93.6109 - val_loss: 71164.7188 - val_mean_absolute_error: 132.4562
# Epoch 152/200
# 55/55 [==============================] - 2s 44ms/step - loss: 31355.8848 - mean_absolute_error: 92.7950 - val_loss: 70475.5547 - val_mean_absolute_error: 131.1466
# Epoch 153/200
# 55/55 [==============================] - 2s 43ms/step - loss: 30902.6895 - mean_absolute_error: 92.0171 - val_loss: 69804.6016 - val_mean_absolute_error: 129.8528
# Epoch 154/200
# 55/55 [==============================] - 2s 43ms/step - loss: 30459.6016 - mean_absolute_error: 91.2731 - val_loss: 69139.4688 - val_mean_absolute_error: 128.5652
# Epoch 155/200
# 55/55 [==============================] - 2s 43ms/step - loss: 30020.5859 - mean_absolute_error: 90.5444 - val_loss: 68474.4453 - val_mean_absolute_error: 127.2943
# Epoch 156/200
# 55/55 [==============================] - 2s 43ms/step - loss: 29592.0820 - mean_absolute_error: 89.8048 - val_loss: 67824.1953 - val_mean_absolute_error: 126.1062
# Epoch 157/200
# 55/55 [==============================] - 2s 43ms/step - loss: 29173.0020 - mean_absolute_error: 89.1102 - val_loss: 67183.9688 - val_mean_absolute_error: 124.9904
# Epoch 158/200
# 55/55 [==============================] - 2s 43ms/step - loss: 28760.1758 - mean_absolute_error: 88.4211 - val_loss: 66555.2734 - val_mean_absolute_error: 123.8838
# Epoch 159/200
# 55/55 [==============================] - 2s 43ms/step - loss: 28359.0781 - mean_absolute_error: 87.7548 - val_loss: 65946.9141 - val_mean_absolute_error: 122.8208
# Epoch 160/200
# 55/55 [==============================] - 2s 43ms/step - loss: 27967.0078 - mean_absolute_error: 87.1715 - val_loss: 65331.2930 - val_mean_absolute_error: 121.7630
# Epoch 161/200
# 55/55 [==============================] - 2s 43ms/step - loss: 27578.9961 - mean_absolute_error: 86.5682 - val_loss: 64728.2930 - val_mean_absolute_error: 120.7071
# Epoch 162/200
# 55/55 [==============================] - 2s 42ms/step - loss: 27203.5996 - mean_absolute_error: 85.9894 - val_loss: 64136.2578 - val_mean_absolute_error: 119.6749
# Epoch 163/200
# 55/55 [==============================] - 2s 43ms/step - loss: 26840.9355 - mean_absolute_error: 85.4511 - val_loss: 63566.0586 - val_mean_absolute_error: 118.6601
# Epoch 164/200
# 55/55 [==============================] - 2s 43ms/step - loss: 26484.5898 - mean_absolute_error: 84.8991 - val_loss: 63006.1719 - val_mean_absolute_error: 117.6893
# Epoch 165/200
# 55/55 [==============================] - 2s 43ms/step - loss: 26131.7070 - mean_absolute_error: 84.3804 - val_loss: 62443.0312 - val_mean_absolute_error: 116.7158
# Epoch 166/200
# 55/55 [==============================] - 2s 43ms/step - loss: 25789.2012 - mean_absolute_error: 83.9102 - val_loss: 61884.4609 - val_mean_absolute_error: 115.7540
# Epoch 167/200
# 55/55 [==============================] - 2s 43ms/step - loss: 25452.2051 - mean_absolute_error: 83.4335 - val_loss: 61346.7109 - val_mean_absolute_error: 114.8293
# Epoch 168/200
# 55/55 [==============================] - 2s 44ms/step - loss: 25124.6680 - mean_absolute_error: 82.9976 - val_loss: 60810.0000 - val_mean_absolute_error: 113.8899
# Epoch 169/200
# 55/55 [==============================] - 2s 43ms/step - loss: 24804.1387 - mean_absolute_error: 82.5734 - val_loss: 60284.0391 - val_mean_absolute_error: 112.9644
# Epoch 170/200
# 55/55 [==============================] - 2s 44ms/step - loss: 24492.9141 - mean_absolute_error: 82.1654 - val_loss: 59767.7812 - val_mean_absolute_error: 112.0653
# Epoch 171/200
# 55/55 [==============================] - 2s 44ms/step - loss: 24190.4531 - mean_absolute_error: 81.7580 - val_loss: 59269.8477 - val_mean_absolute_error: 111.1847
# Epoch 172/200
# 55/55 [==============================] - 2s 43ms/step - loss: 23897.9512 - mean_absolute_error: 81.3925 - val_loss: 58768.7578 - val_mean_absolute_error: 110.3032
# Epoch 173/200
# 55/55 [==============================] - 2s 44ms/step - loss: 23613.8867 - mean_absolute_error: 80.9974 - val_loss: 58305.8984 - val_mean_absolute_error: 109.4511
# Epoch 174/200
# 55/55 [==============================] - 2s 43ms/step - loss: 23338.5215 - mean_absolute_error: 80.6298 - val_loss: 57836.2578 - val_mean_absolute_error: 108.6407
# Epoch 175/200
# 55/55 [==============================] - 2s 43ms/step - loss: 23064.5996 - mean_absolute_error: 80.2763 - val_loss: 57352.8477 - val_mean_absolute_error: 107.8119
# Epoch 176/200
# 55/55 [==============================] - 2s 44ms/step - loss: 22794.6777 - mean_absolute_error: 79.9170 - val_loss: 56893.4102 - val_mean_absolute_error: 107.0373
# Epoch 177/200
# 55/55 [==============================] - 2s 44ms/step - loss: 22537.4531 - mean_absolute_error: 79.5992 - val_loss: 56441.2891 - val_mean_absolute_error: 106.2968
# Epoch 178/200
# 55/55 [==============================] - 2s 44ms/step - loss: 22286.6426 - mean_absolute_error: 79.2748 - val_loss: 56005.4570 - val_mean_absolute_error: 105.5934
# Epoch 179/200
# 55/55 [==============================] - 2s 43ms/step - loss: 22045.1035 - mean_absolute_error: 78.9769 - val_loss: 55575.0977 - val_mean_absolute_error: 104.9056
# Epoch 180/200
# 55/55 [==============================] - 2s 43ms/step - loss: 21807.9062 - mean_absolute_error: 78.6940 - val_loss: 55153.7305 - val_mean_absolute_error: 104.2910
# Epoch 181/200
# 55/55 [==============================] - 2s 43ms/step - loss: 21577.9434 - mean_absolute_error: 78.4124 - val_loss: 54739.1016 - val_mean_absolute_error: 103.7391
# Epoch 182/200
# 55/55 [==============================] - 2s 43ms/step - loss: 21355.7227 - mean_absolute_error: 78.1377 - val_loss: 54326.1602 - val_mean_absolute_error: 103.2174
# Epoch 183/200
# 55/55 [==============================] - 2s 43ms/step - loss: 21144.3770 - mean_absolute_error: 77.8762 - val_loss: 53937.8711 - val_mean_absolute_error: 102.7212
# Epoch 184/200
# 55/55 [==============================] - 2s 43ms/step - loss: 20932.6914 - mean_absolute_error: 77.6256 - val_loss: 53552.5977 - val_mean_absolute_error: 102.2444
# Epoch 185/200
# 55/55 [==============================] - 2s 43ms/step - loss: 20728.7559 - mean_absolute_error: 77.3931 - val_loss: 53164.9375 - val_mean_absolute_error: 101.7754
# Epoch 186/200
# 55/55 [==============================] - 2s 44ms/step - loss: 20532.0000 - mean_absolute_error: 77.1694 - val_loss: 52792.5508 - val_mean_absolute_error: 101.3366
# Epoch 187/200
# 55/55 [==============================] - 2s 43ms/step - loss: 20342.2285 - mean_absolute_error: 76.9510 - val_loss: 52431.2266 - val_mean_absolute_error: 100.9131
# Epoch 188/200
# 55/55 [==============================] - 2s 45ms/step - loss: 20158.7598 - mean_absolute_error: 76.7474 - val_loss: 52082.6641 - val_mean_absolute_error: 100.5019
# Epoch 189/200
# 55/55 [==============================] - 2s 45ms/step - loss: 19979.1387 - mean_absolute_error: 76.5863 - val_loss: 51720.0547 - val_mean_absolute_error: 100.1351
# Epoch 190/200
# 55/55 [==============================] - 2s 44ms/step - loss: 19806.2793 - mean_absolute_error: 76.4161 - val_loss: 51385.4766 - val_mean_absolute_error: 99.8226
# Epoch 191/200
# 55/55 [==============================] - 2s 45ms/step - loss: 19640.7148 - mean_absolute_error: 76.2679 - val_loss: 51055.3008 - val_mean_absolute_error: 99.5305
# Epoch 192/200
# 55/55 [==============================] - 2s 44ms/step - loss: 19479.2598 - mean_absolute_error: 76.1243 - val_loss: 50719.1094 - val_mean_absolute_error: 99.2621
# Epoch 193/200
# 55/55 [==============================] - 2s 44ms/step - loss: 19320.6562 - mean_absolute_error: 75.9859 - val_loss: 50397.2070 - val_mean_absolute_error: 99.0198
# Epoch 194/200
# 55/55 [==============================] - 2s 45ms/step - loss: 19169.7676 - mean_absolute_error: 75.8647 - val_loss: 50089.0195 - val_mean_absolute_error: 98.7921
# Epoch 195/200
# 55/55 [==============================] - 2s 44ms/step - loss: 19027.0449 - mean_absolute_error: 75.7564 - val_loss: 49786.5430 - val_mean_absolute_error: 98.5705
# Epoch 196/200
# 55/55 [==============================] - 2s 44ms/step - loss: 18888.2930 - mean_absolute_error: 75.6606 - val_loss: 49493.0820 - val_mean_absolute_error: 98.4050
# Epoch 197/200
# 55/55 [==============================] - 2s 43ms/step - loss: 18755.9766 - mean_absolute_error: 75.5580 - val_loss: 49203.7227 - val_mean_absolute_error: 98.2734
# Epoch 198/200
# 55/55 [==============================] - 2s 43ms/step - loss: 18626.5938 - mean_absolute_error: 75.4878 - val_loss: 48924.5000 - val_mean_absolute_error: 98.1606
# Epoch 199/200
# 55/55 [==============================] - 2s 44ms/step - loss: 18502.4473 - mean_absolute_error: 75.4040 - val_loss: 48644.3281 - val_mean_absolute_error: 98.0784
# Epoch 200/200
# 55/55 [==============================] - 2s 44ms/step - loss: 18384.7637 - mean_absolute_error: 75.3341 - val_loss: 48391.0273 - val_mean_absolute_error: 97.9762
# 10/10 [==============================] - 0s 9ms/step - loss: 48391.0273 - mean_absolute_error: 97.9762
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-bcf844ac0caa> in <module>()
#      11 changepeople_multi_performance = {}
#      12 changepeople_multi_val_performance['LSTM'] = changepeople_multi_lstm_model.evaluate(multi_window.val)
# ---> 13 changepeople_multi_performance['LSTM'] = changepeople_multi_lstm_model.evaluate(multi_window.test, verbose=0)
#
# <ipython-input-34-fa9c97d26d90> in test(self)
#       9 @property
#      10 def test(self):
# ---> 11   return self.make_dataset(self.test_df)
#      12
#      13 @property
#
# AttributeError: 'WindowGenerator' object has no attribute 'test_df'

# %%
multi_window.changepeople_plot(changepeople_multi_lstm_model)

# %%
changepeople_multi_lstm_model.summary()

# %%
changepeople_multi_lstm_model.evaluate(multi_window.test)

# %%
print('_________________________________________________________________')
print('Model evaluate')
print('=================================================================')
print('Loss: ', changepeople_multi_performance['LSTM'][0])
print('MAE(Mean Absolute Error): ', changepeople_multi_performance['LSTM'][1])
print('=================================================================')

# %%
# 6 훈련 과정 시각화 (MAE)
plt.plot(changepeople_history.history['mean_absolute_error'])
plt.plot(changepeople_history.history['val_mean_absolute_error'])
plt.title('Model MAE(mean absolute error)')
plt.xlabel('Epoch')
plt.ylabel('mean_absolute_error')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# 7 훈련 과정 시각화 (손실)
plt.plot(changepeople_history.history['loss'])
plt.plot(changepeople_history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# # 모델 저장
# changepeople_multi_lstm_model.save('co2_changepeople_multi_lstm_model.h5')
