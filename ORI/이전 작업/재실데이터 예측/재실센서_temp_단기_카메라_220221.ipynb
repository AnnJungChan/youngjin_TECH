# %% [markdown]
# #**단기예측 모델 설계 방향**
# **1. 재실인원 데이터 추가한 다변량 단기 모델(온도, 재실인원)**
# 재실 인원을 카메라로 예측한 데이터로 모델 설계
# - 다변량 단기 예측 모델
#  - 재실인원 추가
#  - 다변량모델 (온도, 재실인원)
#  - 기본 모델인 LSTM으로 인원 예측이 잘 되는지 먼저 확인
#
# - 50분 데이터로 10분 예측
#
# - 예측이 잘된다면 다른 모델로 변경하여 예측할 계획
#
# 1분 단위 리샘플링

# %%
# !pip install PyMySQL
# Out:
# Collecting PyMySQL
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 587 kB/s
# Installing collected packages: PyMySQL
# Successfully installed PyMySQL-1.0.2

# %%
import pymysql

# %%
occupancy_db = pymysql.connect(
    user='datacollection', 
    passwd='collection2021!@', 
    host='121.156.90.144', 
    db='db_datacollection', 
    charset='utf8'
)

# %%
cursor = occupancy_db.cursor(pymysql.cursors.DictCursor)

# %%
sql = "Show Tables;"
cursor.execute(sql)
show = cursor.fetchall()
show
# Out:
# [{'Tables_in_db_datacollection': 'dc_building'},
#  {'Tables_in_db_datacollection': 'dc_device'},
#  {'Tables_in_db_datacollection': 'dc_floor'},
#  {'Tables_in_db_datacollection': 'dc_long_term'},
#  {'Tables_in_db_datacollection': 'dc_people_cnt'},
#  {'Tables_in_db_datacollection': 'dc_pro_mode_define'},
#  {'Tables_in_db_datacollection': 'dc_pro_module'},
#  {'Tables_in_db_datacollection': 'dc_sensor'},
#  {'Tables_in_db_datacollection': 'dc_sensor_data_arduino_1'},
#  {'Tables_in_db_datacollection': 'dc_sensor_data_arduino_1_name'},
#  {'Tables_in_db_datacollection': 'dc_sensor_data_composite_1'},
#  {'Tables_in_db_datacollection': 'dc_sensor_data_temp_camera_1'},
#  {'Tables_in_db_datacollection': 'dc_sensor_data_temp_camera_info'},
#  {'Tables_in_db_datacollection': 'dc_sensor_define'},
#  {'Tables_in_db_datacollection': 'dc_server'},
#  {'Tables_in_db_datacollection': 'dc_short_term'},
#  {'Tables_in_db_datacollection': 'dc_spot'},
#  {'Tables_in_db_datacollection': 'dc_unit_define'},
#  {'Tables_in_db_datacollection': 'dc_vw_origin_code'},
#  {'Tables_in_db_datacollection': 'se_device_temp_cam_log'},
#  {'Tables_in_db_datacollection': 'se_device_temp_cam_log1'},
#  {'Tables_in_db_datacollection': 'se_device_temp_cam_log_copy'},
#  {'Tables_in_db_datacollection': 'se_jaeseok_zone'},
#  {'Tables_in_db_datacollection': 'se_jaeseok_zone1'},
#  {'Tables_in_db_datacollection': 'se_peoplecount_log'},
#  {'Tables_in_db_datacollection': 'tb_incom'},
#  {'Tables_in_db_datacollection': 'tb_jaeseok_onezone'},
#  {'Tables_in_db_datacollection': 'vw_check_incom'},
#  {'Tables_in_db_datacollection': 'vw_data_composite'},
#  {'Tables_in_db_datacollection': 'vw_data_composite_adhd'},
#  {'Tables_in_db_datacollection': 'vw_data_in_check'},
#  {'Tables_in_db_datacollection': 'vw_data_temp_camera'},
#  {'Tables_in_db_datacollection': 'vw_get_dev_module'},
#  {'Tables_in_db_datacollection': 'vw_get_sensor_module'},
#  {'Tables_in_db_datacollection': 'vw_location'},
#  {'Tables_in_db_datacollection': 'vw_sensor_define'}]

# %%
sql = "SELECT sdata_credate, sdata_temp FROM vw_data_composite WHERE sdata_modbus_id=1;"
cursor.execute(sql)
data = cursor.fetchall()

# %%
# tcl_idx, tci_idx, people, changepeople, reg_dte 
sql1 = "SELECT changepeople, reg_dte FROM se_device_temp_cam_log1;"
cursor.execute(sql1)
data1 = cursor.fetchall()

# %%
# tcl_idx, tci_idx, people, changepeople, reg_dte 
sql2 = "SELECT * FROM se_device_temp_cam_log1;"
cursor.execute(sql2)
data2 = cursor.fetchall()

# %%
import pandas as pd

data = pd.DataFrame(data)
data1 = pd.DataFrame(data1)

# %%
# data.to_csv('occupancy_co2_20220217.csv')
# data2.to_csv('occupancy_all_20220222.csv')

# %%
data.rename(columns={'sdata_credate': 'datetime'},inplace=True)
data1.rename(columns={'reg_dte': 'datetime'},inplace=True)

# %%
data['datetime'] = pd.to_datetime(data['datetime'])
data1['datetime'] = pd.to_datetime(data1['datetime'])

# %%
data.set_index('datetime', inplace=True)
data1.set_index('datetime', inplace=True)

# %%
data = data.resample('1T').first()
data=data.loc['2022-02-11 16:32:00':]

# %%
print(data)
print(data1)
# Out:
#                      sdata_temp
# datetime
# 2022-02-11 16:32:00       25.38
# 2022-02-11 16:33:00       25.33
# 2022-02-11 16:34:00       25.29
# 2022-02-11 16:35:00       25.27
# 2022-02-11 16:36:00       25.21
# ...                         ...
# 2022-02-28 16:23:00       25.91
# 2022-02-28 16:24:00       25.92
# 2022-02-28 16:25:00       25.92
# 2022-02-28 16:26:00       25.96
# 2022-02-28 16:27:00       25.96
#
# [24476 rows x 1 columns]
#                      changepeople
# datetime
# 2022-02-11 16:32:00             0
# 2022-02-11 16:33:00             0
# 2022-02-11 17:11:00             0
# 2022-02-11 17:12:00             0
# 2022-02-11 17:13:00             0
# ...                           ...
# 2022-02-28 16:24:00             6
# 2022-02-28 16:25:00             6
# 2022-02-28 16:26:00             6
# 2022-02-28 16:27:00             6
# 2022-02-28 16:28:00             6
#
# [20206 rows x 1 columns]

# %%
merge_df = pd.merge(data, data1, left_index=True, right_index=True, how='left')
merge_df
# Out:
#                      sdata_temp  changepeople
# datetime
# 2022-02-11 16:32:00       25.38           0.0
# 2022-02-11 16:33:00       25.33           0.0
# 2022-02-11 16:34:00       25.29           NaN
# 2022-02-11 16:35:00       25.27           NaN
# 2022-02-11 16:36:00       25.21           NaN
# ...                         ...           ...
# 2022-02-28 16:23:00       25.91           6.0
# 2022-02-28 16:24:00       25.92           6.0
# 2022-02-28 16:25:00       25.92           6.0
# 2022-02-28 16:26:00       25.96           6.0
# 2022-02-28 16:27:00       25.96           6.0
#
# [24476 rows x 2 columns]

# %%
merge_df.fillna(0, inplace=True)

# %%
merge_df['changepeople'].value_counts()
# Out:
#  0.0     12258
# -1.0      3885
#  1.0      1826
# -2.0      1252
#  5.0      1112
#  7.0       944
#  6.0       831
#  4.0       631
#  3.0       535
#  2.0       473
#  8.0       358
#  9.0       177
#  10.0      117
#  12.0       51
#  11.0       26
# Name: changepeople, dtype: int64

# %%
# 인원 수가 마이너스가 나온 경우, 0으로 맞춰줌
for i in range(len(merge_df)):
    if merge_df['changepeople'][i]< 0:
        merge_df['changepeople'][i]=0

# %%
merge_df['changepeople'].value_counts()
# Out:
# 0.0     17395
# 1.0      1826
# 5.0      1112
# 7.0       944
# 6.0       831
# 4.0       631
# 3.0       535
# 2.0       473
# 8.0       358
# 9.0       177
# 10.0      117
# 12.0       51
# 11.0       26
# Name: changepeople, dtype: int64

# %% [markdown]
# # 카메라 기반 재실 데이터 그래프
# - 온도, 재실인원

# %%
import matplotlib.pyplot as plt

merge_df.plot(subplots=True, grid=True, 
           figsize=(26, 4), fontsize=18,
           title='temp & people change data visualization')
plt.show()

# %% [markdown]
# ## 온도 데이터로 단변량 예측

# %%
from keras.models import load_model
import numpy as np

# %%
# 재실밀도 데이터
df = merge_df
column_indices = {name: i for i, name in enumerate(df.columns)}

n = len(df)
train_df = df[0:int(n*0.7)]
val_df = df[int(n*0.7):int(n*0.9)]
test_df = df[int(n*0.9):]

num_features = df.shape[1]

# %%
class WindowGenerator():
  def __init__(self, input_width, label_width, shift,
               train_df=train_df, val_df=val_df, test_df=test_df,
               label_columns=None):
    # Store the raw data.
    self.train_df = train_df
    self.val_df = val_df
    self.test_df = test_df

    # Work out the label column indices.
    self.label_columns = label_columns
    if label_columns is not None:
      self.label_columns_indices = {name: i for i, name in
                                    enumerate(label_columns)}
    self.column_indices = {name: i for i, name in
                           enumerate(train_df.columns)}

    # Work out the window parameters.
    self.input_width = input_width
    self.label_width = label_width
    self.shift = shift

    self.total_window_size = input_width + shift

    self.input_slice = slice(0, input_width)
    self.input_indices = np.arange(self.total_window_size)[self.input_slice]

    self.label_start = self.total_window_size - self.label_width
    self.labels_slice = slice(self.label_start, None)
    self.label_indices = np.arange(self.total_window_size)[self.labels_slice]

  def __repr__(self):
    return '\n'.join([
        f'Total window size: {self.total_window_size}',
        f'Input indices: {self.input_indices}',
        f'Label indices: {self.label_indices}',
        f'Label column name(s): {self.label_columns}'])

# %%
w1 = WindowGenerator(input_width=50, label_width=1, shift=50,
                         label_columns=['sdata_temp', 'changepeople'])

# %%
w2 = WindowGenerator(input_width=10, label_width=1, shift=1,
                         label_columns=['sdata_temp','changepeople'])

# %%
def split_window(self, features):
  inputs = features[:, self.input_slice, :]
  labels = features[:, self.labels_slice, :]
  if self.label_columns is not None:
    labels = tf.stack(
        [labels[:, :, self.column_indices[name]] for name in self.label_columns],
        axis=-1)

  # Slicing doesn't preserve static shape information, so set the shapes
  # manually. This way the `tf.data.Datasets` are easier to inspect.
  inputs.set_shape([None, self.input_width, None])
  labels.set_shape([None, self.label_width, None])

  return inputs, labels

WindowGenerator.split_window = split_window

# %%
import tensorflow as tf

# Stack three slices, the length of the total window:
window = tf.stack([np.array(train_df[:w2.total_window_size]),
                           np.array(train_df[100:100+w2.total_window_size]),
                           np.array(train_df[200:200+w2.total_window_size])])

inputs, labels = w2.split_window(window)

print('Temperature shapes are: (batch, time, features)')
print(f'Window shape: {window.shape}')
print(f'Inputs shape: {inputs.shape}')
print(f'labels shape: {labels.shape}\n')
# Out:
# Temperature shapes are: (batch, time, features)
# Window shape: (3, 11, 2)
# Inputs shape: (3, 10, 2)
# labels shape: (3, 1, 2)

# %%
w2.example = inputs, labels

# %%
# temp
def temp_plot(self, model=None, plot_col='sdata_temp', max_subplots=3):
  inputs, labels = self.example
  plt.figure(figsize=(20, 10))
  plot_col_index = self.column_indices[plot_col]
  max_n = min(max_subplots, len(inputs))
  for n in range(max_n):
    plt.subplot(3, 1, n+1)
    plt.ylabel(f'{plot_col}')
    plt.plot(self.input_indices, inputs[n, :, plot_col_index],
             label='Inputs', marker='.', zorder=-10)

    if self.label_columns:
      label_col_index = self.label_columns_indices.get(plot_col, None)
    else:
      label_col_index = plot_col_index

    if label_col_index is None:
      continue

    plt.scatter(self.label_indices, labels[n, :, label_col_index],
                edgecolors='k', label='Labels', c='#2ca02c', s=64)
    if model is not None:
      predictions = model(inputs)
      plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                  marker='X', edgecolors='k', label='Predictions',
                  c='#ff7f0e', s=64)

    if n == 0:
      plt.legend()

  plt.xlabel('Time [1m]')

WindowGenerator.temp_plot = temp_plot

# change people
def changepeople_plot(self, model=None, plot_col='changepeople', max_subplots=3):
  inputs, labels = self.example
  plt.figure(figsize=(20, 10))
  plot_col_index = self.column_indices[plot_col]
  max_n = min(max_subplots, len(inputs))
  for n in range(max_n):
    plt.subplot(3, 1, n+1)
    plt.ylabel(f'{plot_col}')
    plt.plot(self.input_indices, inputs[n, :, plot_col_index],
             label='Inputs', marker='.', zorder=-10)

    if self.label_columns:
      label_col_index = self.label_columns_indices.get(plot_col, None)
    else:
      label_col_index = plot_col_index

    if label_col_index is None:
      continue

    plt.scatter(self.label_indices, labels[n, :, label_col_index],
                edgecolors='k', label='Labels', c='#2ca02c', s=64)
    if model is not None:
      predictions = model(inputs)
      plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                  marker='X', edgecolors='k', label='Predictions',
                  c='#ff7f0e', s=64)

    if n == 0:
      plt.legend()

  plt.xlabel('Time [1m]')

WindowGenerator.changepeople_plot = changepeople_plot

# %%
def make_dataset(self, data):
  data = np.array(data, dtype=np.float32)
  ds = tf.keras.preprocessing.timeseries_dataset_from_array(
      data=data,
      targets=None,
      sequence_length=self.total_window_size,
      sequence_stride=1,
      shuffle=True,
      batch_size=32,)

  ds = ds.map(self.split_window)

  return ds

WindowGenerator.make_dataset = make_dataset

# %%
@property
def train(self):
  return self.make_dataset(self.train_df)

@property
def val(self):
  return self.make_dataset(self.val_df)

@property
def test(self):
  return self.make_dataset(self.test_df)

@property
def example(self):
  """Get and cache an example batch of `inputs, labels` for plotting."""
  result = getattr(self, '_example', None)
  if result is None:
    # No example batch was found, so get one from the `.train` dataset
    result = next(iter(self.train))
    # And cache it for next time
    self._example = result
  return result

WindowGenerator.train = train
WindowGenerator.val = val
WindowGenerator.test = test
WindowGenerator.example = example

# %%
w2.train.element_spec
# Out:
# (TensorSpec(shape=(None, 10, 2), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None, 1, 2), dtype=tf.float32, name=None))

# %%
OUT_STEPS=10
multi_window = WindowGenerator(input_width=50,
                                   label_width=OUT_STEPS,
                                   shift=OUT_STEPS)

multi_window
multi_window.temp_plot()

# %%
print(len(multi_window.train))
print(len(multi_window.val))
print(len(multi_window.test))
# Out:
# 534
# 152
# 75

# %%
MAX_EPOCHS = 100

def compile_and_fit(model, window, patience=5):
  early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                    patience=patience,
                                                    mode='min')

  model.compile(loss=tf.losses.MeanSquaredError(),
                optimizer=tf.optimizers.Adam(),
                metrics=[tf.metrics.MeanAbsoluteError()])

  history = model.fit(window.train, epochs=MAX_EPOCHS,
                      validation_data=window.val,
                      callbacks=[early_stopping])
  return history

# %% [markdown]
# ### 온도

# %%
temp_multi_lstm_model = tf.keras.Sequential([
    tf.keras.layers.LSTM(128, return_sequences=False),
    tf.keras.layers.Dense(OUT_STEPS*num_features,
                          kernel_initializer=tf.initializers.zeros),
    tf.keras.layers.Reshape([OUT_STEPS, num_features])
])

temp_history = compile_and_fit(temp_multi_lstm_model, multi_window)

temp_multi_val_performance = {}
temp_multi_performance = {}
temp_multi_val_performance['LSTM'] = temp_multi_lstm_model.evaluate(multi_window.val)
temp_multi_performance['LSTM'] = temp_multi_lstm_model.evaluate(multi_window.test, verbose=0)

multi_window.temp_plot(temp_multi_lstm_model)
# Out:
# Epoch 1/100
# 346/346 [==============================] - 30s 77ms/step - loss: 43.8377 - mean_absolute_error: 4.0717 - val_loss: 5.8485 - val_mean_absolute_error: 1.8967
# Epoch 2/100
# 346/346 [==============================] - 18s 52ms/step - loss: 5.8793 - mean_absolute_error: 1.8968 - val_loss: 6.0967 - val_mean_absolute_error: 1.9109
# Epoch 3/100
# 346/346 [==============================] - 18s 52ms/step - loss: 3.9027 - mean_absolute_error: 1.4306 - val_loss: 1.9605 - val_mean_absolute_error: 0.8844
# Epoch 4/100
# 346/346 [==============================] - 19s 54ms/step - loss: 1.0077 - mean_absolute_error: 0.5886 - val_loss: 0.8749 - val_mean_absolute_error: 0.6035
# Epoch 5/100
# 346/346 [==============================] - 20s 56ms/step - loss: 0.4844 - mean_absolute_error: 0.3687 - val_loss: 0.6187 - val_mean_absolute_error: 0.4613
# Epoch 6/100
# 346/346 [==============================] - 20s 56ms/step - loss: 0.2946 - mean_absolute_error: 0.2735 - val_loss: 0.3572 - val_mean_absolute_error: 0.3312
# Epoch 7/100
# 346/346 [==============================] - 18s 53ms/step - loss: 0.2015 - mean_absolute_error: 0.2124 - val_loss: 0.2705 - val_mean_absolute_error: 0.2653
# Epoch 8/100
# 346/346 [==============================] - 23s 66ms/step - loss: 0.1553 - mean_absolute_error: 0.1704 - val_loss: 0.1818 - val_mean_absolute_error: 0.1929
# Epoch 9/100
# 346/346 [==============================] - 18s 52ms/step - loss: 0.1385 - mean_absolute_error: 0.1545 - val_loss: 0.1641 - val_mean_absolute_error: 0.1866
# Epoch 10/100
# 346/346 [==============================] - 20s 56ms/step - loss: 0.1299 - mean_absolute_error: 0.1445 - val_loss: 0.1522 - val_mean_absolute_error: 0.1636
# Epoch 11/100
# 346/346 [==============================] - 18s 51ms/step - loss: 0.1251 - mean_absolute_error: 0.1381 - val_loss: 0.1518 - val_mean_absolute_error: 0.1813
# Epoch 12/100
# 346/346 [==============================] - 18s 51ms/step - loss: 0.1236 - mean_absolute_error: 0.1396 - val_loss: 0.1542 - val_mean_absolute_error: 0.1787
# Epoch 13/100
# 346/346 [==============================] - 18s 52ms/step - loss: 0.1221 - mean_absolute_error: 0.1379 - val_loss: 0.1373 - val_mean_absolute_error: 0.1390
# Epoch 14/100
# 346/346 [==============================] - 18s 52ms/step - loss: 0.1180 - mean_absolute_error: 0.1293 - val_loss: 0.1370 - val_mean_absolute_error: 0.1424
# Epoch 15/100
# 346/346 [==============================] - 18s 52ms/step - loss: 0.1165 - mean_absolute_error: 0.1270 - val_loss: 0.1376 - val_mean_absolute_error: 0.1400
# Epoch 16/100
# 346/346 [==============================] - 18s 51ms/step - loss: 0.1176 - mean_absolute_error: 0.1302 - val_loss: 0.1524 - val_mean_absolute_error: 0.2053
# Epoch 17/100
# 346/346 [==============================] - 18s 52ms/step - loss: 0.1157 - mean_absolute_error: 0.1288 - val_loss: 0.1365 - val_mean_absolute_error: 0.1509
# Epoch 18/100
# 346/346 [==============================] - 18s 51ms/step - loss: 0.1136 - mean_absolute_error: 0.1233 - val_loss: 0.1393 - val_mean_absolute_error: 0.1587
# Epoch 19/100
# 346/346 [==============================] - 18s 51ms/step - loss: 0.1135 - mean_absolute_error: 0.1226 - val_loss: 0.1377 - val_mean_absolute_error: 0.1473
# Epoch 20/100
# 346/346 [==============================] - 18s 51ms/step - loss: 0.1132 - mean_absolute_error: 0.1245 - val_loss: 0.1420 - val_mean_absolute_error: 0.1424
# Epoch 21/100
# 346/346 [==============================] - 18s 52ms/step - loss: 0.1126 - mean_absolute_error: 0.1242 - val_loss: 0.1277 - val_mean_absolute_error: 0.1243
# Epoch 22/100
# 346/346 [==============================] - 20s 59ms/step - loss: 0.1125 - mean_absolute_error: 0.1268 - val_loss: 0.1335 - val_mean_absolute_error: 0.1261
# Epoch 23/100
# 346/346 [==============================] - 19s 54ms/step - loss: 0.1116 - mean_absolute_error: 0.1230 - val_loss: 0.1402 - val_mean_absolute_error: 0.1538
# Epoch 24/100
# 346/346 [==============================] - 20s 57ms/step - loss: 0.1115 - mean_absolute_error: 0.1240 - val_loss: 0.1292 - val_mean_absolute_error: 0.1279
# Epoch 25/100
# 346/346 [==============================] - 18s 52ms/step - loss: 0.1111 - mean_absolute_error: 0.1248 - val_loss: 0.1290 - val_mean_absolute_error: 0.1346
# Epoch 26/100
# 346/346 [==============================] - 18s 52ms/step - loss: 0.1101 - mean_absolute_error: 0.1221 - val_loss: 0.1283 - val_mean_absolute_error: 0.1186
# 98/98 [==============================] - 2s 19ms/step - loss: 0.1283 - mean_absolute_error: 0.1186

# %%
temp_multi_lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               67072
#
#  dense (Dense)               (None, 20)                2580
#
#  reshape (Reshape)           (None, 10, 2)             0
#
# =================================================================
# Total params: 69,652
# Trainable params: 69,652
# Non-trainable params: 0
# _________________________________________________________________

# %%
temp_multi_lstm_model.evaluate(multi_window.test)
# Out:
# 48/48 [==============================] - 1s 18ms/step - loss: 0.2483 - mean_absolute_error: 0.1907
# [0.24825698137283325, 0.1906629204750061]

# %%
print('_________________________________________________________________')
print('Model evaluate')
print('=================================================================')
print('Loss: ', temp_multi_performance['LSTM'][0])
print('MAE(Mean Absolute Error): ', temp_multi_performance['LSTM'][1])
print('=================================================================')
# Out:
# _________________________________________________________________
# Model evaluate
# =================================================================
# Loss:  0.24825702607631683
# MAE(Mean Absolute Error):  0.1906629353761673
# =================================================================

# %%
# 6 훈련 과정 시각화 (MAE)
plt.plot(temp_history.history['mean_absolute_error'])
plt.plot(temp_history.history['val_mean_absolute_error'])
plt.title('Model MAE(mean absolute error)')
plt.xlabel('Epoch')
plt.ylabel('mean_absolute_error')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# 7 훈련 과정 시각화 (손실)
plt.plot(temp_history.history['loss'])
plt.plot(temp_history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# # 모델 저장
# temp_multi_lstm_model.save('temp_multi_lstm_model.h5')

# %%
changepeople_multi_lstm_model = tf.keras.Sequential([
    tf.keras.layers.LSTM(128, return_sequences=False),
    tf.keras.layers.Dense(OUT_STEPS*num_features,
                          kernel_initializer=tf.initializers.zeros),
    tf.keras.layers.Reshape([OUT_STEPS, num_features])
])

changepeople_history = compile_and_fit(changepeople_multi_lstm_model, multi_window)

changepeople_multi_val_performance = {}
changepeople_multi_performance = {}
changepeople_multi_val_performance['LSTM'] = changepeople_multi_lstm_model.evaluate(multi_window.val)
changepeople_multi_performance['LSTM'] = changepeople_multi_lstm_model.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/100
# 346/346 [==============================] - 21s 53ms/step - loss: 43.7538 - mean_absolute_error: 4.0629 - val_loss: 5.8508 - val_mean_absolute_error: 1.9038
# Epoch 2/100
# 346/346 [==============================] - 18s 52ms/step - loss: 5.8780 - mean_absolute_error: 1.8944 - val_loss: 5.9121 - val_mean_absolute_error: 1.9672
# Epoch 3/100
# 346/346 [==============================] - 18s 52ms/step - loss: 3.7792 - mean_absolute_error: 1.3946 - val_loss: 1.3520 - val_mean_absolute_error: 0.7079
# Epoch 4/100
# 346/346 [==============================] - 18s 51ms/step - loss: 0.8808 - mean_absolute_error: 0.5310 - val_loss: 0.5854 - val_mean_absolute_error: 0.4380
# Epoch 5/100
# 346/346 [==============================] - 18s 51ms/step - loss: 0.3457 - mean_absolute_error: 0.3030 - val_loss: 0.3471 - val_mean_absolute_error: 0.3544
# Epoch 6/100
# 346/346 [==============================] - 18s 52ms/step - loss: 0.1977 - mean_absolute_error: 0.2164 - val_loss: 0.2394 - val_mean_absolute_error: 0.2855
# Epoch 7/100
# 346/346 [==============================] - 18s 52ms/step - loss: 0.1548 - mean_absolute_error: 0.1771 - val_loss: 0.1900 - val_mean_absolute_error: 0.2312
# Epoch 8/100
# 346/346 [==============================] - 18s 51ms/step - loss: 0.1392 - mean_absolute_error: 0.1635 - val_loss: 0.1636 - val_mean_absolute_error: 0.1957
# Epoch 9/100
# 346/346 [==============================] - 18s 51ms/step - loss: 0.1300 - mean_absolute_error: 0.1498 - val_loss: 0.1581 - val_mean_absolute_error: 0.1901
# Epoch 10/100
# 346/346 [==============================] - 18s 52ms/step - loss: 0.1250 - mean_absolute_error: 0.1412 - val_loss: 0.1504 - val_mean_absolute_error: 0.1716
# Epoch 11/100
# 346/346 [==============================] - 20s 57ms/step - loss: 0.1237 - mean_absolute_error: 0.1425 - val_loss: 0.1527 - val_mean_absolute_error: 0.1760
# Epoch 12/100
# 346/346 [==============================] - 23s 65ms/step - loss: 0.1236 - mean_absolute_error: 0.1446 - val_loss: 0.1418 - val_mean_absolute_error: 0.1614
# Epoch 13/100
# 346/346 [==============================] - 18s 51ms/step - loss: 0.1230 - mean_absolute_error: 0.1461 - val_loss: 0.1478 - val_mean_absolute_error: 0.1574
# Epoch 14/100
# 346/346 [==============================] - 20s 59ms/step - loss: 0.1236 - mean_absolute_error: 0.1427 - val_loss: 0.1586 - val_mean_absolute_error: 0.1981
# Epoch 15/100
# 346/346 [==============================] - 18s 51ms/step - loss: 0.1193 - mean_absolute_error: 0.1370 - val_loss: 0.1457 - val_mean_absolute_error: 0.1623
# Epoch 16/100
# 346/346 [==============================] - 18s 52ms/step - loss: 0.1177 - mean_absolute_error: 0.1339 - val_loss: 0.1446 - val_mean_absolute_error: 0.1455
# Epoch 17/100
# 346/346 [==============================] - 18s 52ms/step - loss: 0.1186 - mean_absolute_error: 0.1349 - val_loss: 0.1515 - val_mean_absolute_error: 0.1724
# 98/98 [==============================] - 2s 19ms/step - loss: 0.1515 - mean_absolute_error: 0.1724

# %%
multi_window.changepeople_plot(changepeople_multi_lstm_model)

# %%
changepeople_multi_lstm_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 128)               67072
#
#  dense_1 (Dense)             (None, 20)                2580
#
#  reshape_1 (Reshape)         (None, 10, 2)             0
#
# =================================================================
# Total params: 69,652
# Trainable params: 69,652
# Non-trainable params: 0
# _________________________________________________________________

# %%
changepeople_multi_lstm_model.evaluate(multi_window.test)
# Out:
# 48/48 [==============================] - 1s 18ms/step - loss: 0.2632 - mean_absolute_error: 0.2321
# [0.26316192746162415, 0.23210661113262177]

# %%
print('_________________________________________________________________')
print('Model evaluate')
print('=================================================================')
print('Loss: ', changepeople_multi_performance['LSTM'][0])
print('MAE(Mean Absolute Error): ', changepeople_multi_performance['LSTM'][1])
print('=================================================================')
# Out:
# _________________________________________________________________
# Model evaluate
# =================================================================
# Loss:  0.26316189765930176
# MAE(Mean Absolute Error):  0.23210661113262177
# =================================================================

# %%
# 6 훈련 과정 시각화 (MAE)
plt.plot(changepeople_history.history['mean_absolute_error'])
plt.plot(changepeople_history.history['val_mean_absolute_error'])
plt.title('Model MAE(mean absolute error)')
plt.xlabel('Epoch')
plt.ylabel('mean_absolute_error')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# 7 훈련 과정 시각화 (손실)
plt.plot(changepeople_history.history['loss'])
plt.plot(changepeople_history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# # 모델 저장
# changepeople_multi_lstm_model.save('temp_changepeople_multi_lstm_model.h5')
