# %% [markdown]
# #**단기예측 모델 설계 방향**
# **1. 재실인원 데이터 추가한 다변량 단기 모델(co2, 재실인원)**
# 재실 인원을 카메라로 예측한 데이터로 모델 설계
# - 다변량 단기 예측 모델
#  - 재실인원 추가
#  - 다변량모델 (co2, 재실인원)
#  - 기본 모델인 LSTM으로 인원 예측이 잘 되는지 먼저 확인
# - 50분의 데이터로 10분의 재실인원 예측
# - 예측이 잘된다면 다른 모델로 변경하여 예측할 계획
#
# 1분 단위 리샘플링

# %%
# !pip install PyMySQL
# Out:
# Collecting PyMySQL
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 719 kB/s
# Installing collected packages: PyMySQL
# Successfully installed PyMySQL-1.0.2

# %%
import pymysql

# %%
occupancy_db = pymysql.connect(
    user='datacollection', 
    passwd='collection2021!@', 
    host='121.156.90.144', 
    db='db_datacollection', 
    charset='utf8'
)

# %%
cursor = occupancy_db.cursor(pymysql.cursors.DictCursor)

# %%
sql = "Show Tables;"
cursor.execute(sql)
show = cursor.fetchall()
show
# Out:
# [{'Tables_in_db_datacollection': 'dc_building'},
#  {'Tables_in_db_datacollection': 'dc_device'},
#  {'Tables_in_db_datacollection': 'dc_floor'},
#  {'Tables_in_db_datacollection': 'dc_long_term'},
#  {'Tables_in_db_datacollection': 'dc_people_cnt'},
#  {'Tables_in_db_datacollection': 'dc_pro_mode_define'},
#  {'Tables_in_db_datacollection': 'dc_pro_module'},
#  {'Tables_in_db_datacollection': 'dc_sensor'},
#  {'Tables_in_db_datacollection': 'dc_sensor_data_arduino_1'},
#  {'Tables_in_db_datacollection': 'dc_sensor_data_arduino_1_name'},
#  {'Tables_in_db_datacollection': 'dc_sensor_data_composite_1'},
#  {'Tables_in_db_datacollection': 'dc_sensor_data_temp_camera_1'},
#  {'Tables_in_db_datacollection': 'dc_sensor_data_temp_camera_info'},
#  {'Tables_in_db_datacollection': 'dc_sensor_define'},
#  {'Tables_in_db_datacollection': 'dc_server'},
#  {'Tables_in_db_datacollection': 'dc_short_term'},
#  {'Tables_in_db_datacollection': 'dc_spot'},
#  {'Tables_in_db_datacollection': 'dc_unit_define'},
#  {'Tables_in_db_datacollection': 'dc_vw_origin_code'},
#  {'Tables_in_db_datacollection': 'se_device_temp_cam_log'},
#  {'Tables_in_db_datacollection': 'se_device_temp_cam_log1'},
#  {'Tables_in_db_datacollection': 'se_device_temp_cam_log_copy'},
#  {'Tables_in_db_datacollection': 'se_jaeseok_zone'},
#  {'Tables_in_db_datacollection': 'se_jaeseok_zone1'},
#  {'Tables_in_db_datacollection': 'se_peoplecount_log'},
#  {'Tables_in_db_datacollection': 'tb_incom'},
#  {'Tables_in_db_datacollection': 'tb_jaeseok_onezone'},
#  {'Tables_in_db_datacollection': 'vw_check_incom'},
#  {'Tables_in_db_datacollection': 'vw_data_composite'},
#  {'Tables_in_db_datacollection': 'vw_data_composite_adhd'},
#  {'Tables_in_db_datacollection': 'vw_data_in_check'},
#  {'Tables_in_db_datacollection': 'vw_data_temp_camera'},
#  {'Tables_in_db_datacollection': 'vw_get_dev_module'},
#  {'Tables_in_db_datacollection': 'vw_get_sensor_module'},
#  {'Tables_in_db_datacollection': 'vw_location'},
#  {'Tables_in_db_datacollection': 'vw_sensor_define'}]

# %%
sql = "SELECT sdata_credate, sdata_co2 FROM vw_data_composite WHERE sdata_modbus_id=1;"
cursor.execute(sql)
data = cursor.fetchall()

# %%
# tcl_idx, tci_idx, people, changepeople, reg_dte 
sql1 = "SELECT changepeople, reg_dte FROM se_device_temp_cam_log1;"
cursor.execute(sql1)
data1 = cursor.fetchall()

# %%
# tcl_idx, tci_idx, people, changepeople, reg_dte 
sql2 = "SELECT * FROM se_device_temp_cam_log1;"
cursor.execute(sql2)
data2 = cursor.fetchall()

# %%
import pandas as pd

data = pd.DataFrame(data)
data1 = pd.DataFrame(data1)

# %%
data2 = pd.DataFrame(data2)

# %%
# data.to_csv('occupancy_co2_20220217.csv')
data2.to_csv('occupancy_all_20220222.csv')

# %%
data.rename(columns={'sdata_credate': 'datetime'},inplace=True)
data1.rename(columns={'reg_dte': 'datetime'},inplace=True)

# %%
data['datetime'] = pd.to_datetime(data['datetime'])
data1['datetime'] = pd.to_datetime(data1['datetime'])

# %%
data.set_index('datetime', inplace=True)
data1.set_index('datetime', inplace=True)

# %%
data = data.resample('1T').first()
data=data.loc['2022-02-11 16:32:00':]

# %%
print(data)
print(data1)
# Out:
#                      sdata_co2
# datetime
# 2022-02-11 16:32:00     1065.0
# 2022-02-11 16:33:00     1055.0
# 2022-02-11 16:34:00     1047.0
# 2022-02-11 16:35:00     1046.0
# 2022-02-11 16:36:00     1048.0
# ...                        ...
# 2022-02-25 16:37:00     1045.0
# 2022-02-25 16:38:00     1048.0
# 2022-02-25 16:39:00     1049.0
# 2022-02-25 16:40:00     1049.0
# 2022-02-25 16:41:00     1047.0
#
# [20170 rows x 1 columns]
#                      changepeople
# datetime
# 2022-02-11 16:32:00             0
# 2022-02-11 16:33:00             0
# 2022-02-11 17:11:00             0
# 2022-02-11 17:12:00             0
# 2022-02-11 17:13:00             0
# ...                           ...
# 2022-02-25 16:38:00             3
# 2022-02-25 16:39:00             3
# 2022-02-25 16:40:00             3
# 2022-02-25 16:41:00             3
# 2022-02-25 16:42:00             2
#
# [15900 rows x 1 columns]

# %%
# index 열 개수가 맞지 않아서 인덱스 기준 merge가 불가능
merge_df = pd.merge(data, data1, left_index=True, right_index=True, how='left')
merge_df
# Out:
#                      sdata_co2  changepeople
# datetime
# 2022-02-11 16:32:00     1065.0           0.0
# 2022-02-11 16:33:00     1055.0           0.0
# 2022-02-11 16:34:00     1047.0           NaN
# 2022-02-11 16:35:00     1046.0           NaN
# 2022-02-11 16:36:00     1048.0           NaN
# ...                        ...           ...
# 2022-02-25 16:37:00     1045.0           3.0
# 2022-02-25 16:38:00     1048.0           3.0
# 2022-02-25 16:39:00     1049.0           3.0
# 2022-02-25 16:40:00     1049.0           3.0
# 2022-02-25 16:41:00     1047.0           3.0
#
# [20170 rows x 2 columns]

# %%
merge_df.fillna(0, inplace=True)

# %%
merge_df['changepeople'].value_counts()
# Out:
#  0.0     9918
# -1.0     3535
#  1.0     1075
#  5.0     1042
# -2.0     1035
#  7.0      874
#  6.0      717
#  4.0      570
#  3.0      504
#  8.0      314
#  2.0      280
#  9.0      172
#  10.0     111
#  11.0      23
# Name: changepeople, dtype: int64

# %%
# 인원 수가 마이너스가 나온 경우, 0으로 맞춰줌
for i in range(15739):
    if merge_df['changepeople'][i]< 0:
        merge_df['changepeople'][i]=0

# %%
merge_df['changepeople'].value_counts()
# Out:
#  0.0     13300
#  1.0      1075
#  5.0      1042
#  7.0       874
#  6.0       717
# -1.0       654
#  4.0       570
# -2.0       534
#  3.0       504
#  8.0       314
#  2.0       280
#  9.0       172
#  10.0      111
#  11.0       23
# Name: changepeople, dtype: int64

# %% [markdown]
# # 카메라 기반 재실 데이터 그래프
# - 이산화탄소, 재실인원

# %%
import matplotlib.pyplot as plt

merge_df.plot(subplots=True, grid=True, 
           figsize=(26, 4), fontsize=18,
           title='co2 & people change data visualization')
plt.show()

# %% [markdown]
# ## 이산화탄소 데이터로 단변량 예측

# %%
from keras.models import load_model
import numpy as np

# %%
# 재실밀도 데이터
df = merge_df
column_indices = {name: i for i, name in enumerate(df.columns)}

n = len(df)
train_df = df[0:int(n*0.7)]
val_df = df[int(n*0.7):int(n*0.9)]
test_df = df[int(n*0.9):]

num_features = df.shape[1]

# %%
class WindowGenerator():
  def __init__(self, input_width, label_width, shift,
               train_df=train_df, val_df=val_df, test_df=test_df,
               label_columns=None):
    # Store the raw data.
    self.train_df = train_df
    self.val_df = val_df
    self.test_df = test_df

    # Work out the label column indices.
    self.label_columns = label_columns
    if label_columns is not None:
      self.label_columns_indices = {name: i for i, name in
                                    enumerate(label_columns)}
    self.column_indices = {name: i for i, name in
                           enumerate(train_df.columns)}

    # Work out the window parameters.
    self.input_width = input_width
    self.label_width = label_width
    self.shift = shift

    self.total_window_size = input_width + shift

    self.input_slice = slice(0, input_width)
    self.input_indices = np.arange(self.total_window_size)[self.input_slice]

    self.label_start = self.total_window_size - self.label_width
    self.labels_slice = slice(self.label_start, None)
    self.label_indices = np.arange(self.total_window_size)[self.labels_slice]

  def __repr__(self):
    return '\n'.join([
        f'Total window size: {self.total_window_size}',
        f'Input indices: {self.input_indices}',
        f'Label indices: {self.label_indices}',
        f'Label column name(s): {self.label_columns}'])

# %%
w1 = WindowGenerator(input_width=50, label_width=1, shift=50,
                         label_columns=['sdata_co2', 'changepeople'])

# %%
w2 = WindowGenerator(input_width=10, label_width=1, shift=1,
                         label_columns=['sdata_co2','changepeople'])

# %%
def split_window(self, features):
  inputs = features[:, self.input_slice, :]
  labels = features[:, self.labels_slice, :]
  if self.label_columns is not None:
    labels = tf.stack(
        [labels[:, :, self.column_indices[name]] for name in self.label_columns],
        axis=-1)

  # Slicing doesn't preserve static shape information, so set the shapes
  # manually. This way the `tf.data.Datasets` are easier to inspect.
  inputs.set_shape([None, self.input_width, None])
  labels.set_shape([None, self.label_width, None])

  return inputs, labels

WindowGenerator.split_window = split_window

# %%
import tensorflow as tf

# Stack three slices, the length of the total window:
window = tf.stack([np.array(train_df[:w2.total_window_size]),
                           np.array(train_df[100:100+w2.total_window_size]),
                           np.array(train_df[200:200+w2.total_window_size])])

inputs, labels = w2.split_window(window)

print('Temperature shapes are: (batch, time, features)')
print(f'Window shape: {window.shape}')
print(f'Inputs shape: {inputs.shape}')
print(f'labels shape: {labels.shape}\n')
# Out:
# Temperature shapes are: (batch, time, features)
# Window shape: (3, 11, 2)
# Inputs shape: (3, 10, 2)
# labels shape: (3, 1, 2)

# %%
w2.example = inputs, labels

# %%
# co2
def co2_plot(self, model=None, plot_col='sdata_co2', max_subplots=3):
  inputs, labels = self.example
  plt.figure(figsize=(20, 10))
  plot_col_index = self.column_indices[plot_col]
  max_n = min(max_subplots, len(inputs))
  for n in range(max_n):
    plt.subplot(3, 1, n+1)
    plt.ylabel(f'{plot_col}')
    plt.plot(self.input_indices, inputs[n, :, plot_col_index],
             label='Inputs', marker='.', zorder=-10)

    if self.label_columns:
      label_col_index = self.label_columns_indices.get(plot_col, None)
    else:
      label_col_index = plot_col_index

    if label_col_index is None:
      continue

    plt.scatter(self.label_indices, labels[n, :, label_col_index],
                edgecolors='k', label='Labels', c='#2ca02c', s=64)
    if model is not None:
      predictions = model(inputs)
      plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                  marker='X', edgecolors='k', label='Predictions',
                  c='#ff7f0e', s=64)

    if n == 0:
      plt.legend()

  plt.xlabel('Time [1m]')

WindowGenerator.co2_plot = co2_plot

# change people
def changepeople_plot(self, model=None, plot_col='changepeople', max_subplots=3):
  inputs, labels = self.example
  plt.figure(figsize=(20, 10))
  plot_col_index = self.column_indices[plot_col]
  max_n = min(max_subplots, len(inputs))
  for n in range(max_n):
    plt.subplot(3, 1, n+1)
    plt.ylabel(f'{plot_col}')
    plt.plot(self.input_indices, inputs[n, :, plot_col_index],
             label='Inputs', marker='.', zorder=-10)

    if self.label_columns:
      label_col_index = self.label_columns_indices.get(plot_col, None)
    else:
      label_col_index = plot_col_index

    if label_col_index is None:
      continue

    plt.scatter(self.label_indices, labels[n, :, label_col_index],
                edgecolors='k', label='Labels', c='#2ca02c', s=64)
    if model is not None:
      predictions = model(inputs)
      plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                  marker='X', edgecolors='k', label='Predictions',
                  c='#ff7f0e', s=64)

    if n == 0:
      plt.legend()

  plt.xlabel('Time [1m]')

WindowGenerator.changepeople_plot = changepeople_plot

# %%
def make_dataset(self, data):
  data = np.array(data, dtype=np.float32)
  ds = tf.keras.preprocessing.timeseries_dataset_from_array(
      data=data,
      targets=None,
      sequence_length=self.total_window_size,
      sequence_stride=1,
      shuffle=True,
      batch_size=32,)

  ds = ds.map(self.split_window)

  return ds

WindowGenerator.make_dataset = make_dataset

# %%
@property
def train(self):
  return self.make_dataset(self.train_df)

@property
def val(self):
  return self.make_dataset(self.val_df)

@property
def test(self):
  return self.make_dataset(self.test_df)

@property
def example(self):
  """Get and cache an example batch of `inputs, labels` for plotting."""
  result = getattr(self, '_example', None)
  if result is None:
    # No example batch was found, so get one from the `.train` dataset
    result = next(iter(self.train))
    # And cache it for next time
    self._example = result
  return result

WindowGenerator.train = train
WindowGenerator.val = val
WindowGenerator.test = test
WindowGenerator.example = example

# %%
w2.train.element_spec
# Out:
# (TensorSpec(shape=(None, 10, 2), dtype=tf.float32, name=None),
#  TensorSpec(shape=(None, 1, 2), dtype=tf.float32, name=None))

# %%
OUT_STEPS=10
multi_window = WindowGenerator(input_width=50,
                                   label_width=OUT_STEPS,
                                   shift=OUT_STEPS)

multi_window
multi_window.co2_plot()

# %%
MAX_EPOCHS = 100

def compile_and_fit(model, window, patience=5):
  early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                    patience=patience,
                                                    mode='min')

  model.compile(loss=tf.losses.MeanSquaredError(),
                optimizer=tf.optimizers.Adam(),
                metrics=[tf.metrics.MeanAbsoluteError()])

  history = model.fit(window.train, epochs=MAX_EPOCHS,
                      validation_data=window.val,
                      callbacks=[early_stopping])
  return history

# %% [markdown]
# ### 이산화탄소

# %%
co2_multi_lstm_model = tf.keras.Sequential([
    tf.keras.layers.LSTM(128, return_sequences=False),
    tf.keras.layers.Dense(OUT_STEPS*num_features,
                          kernel_initializer=tf.initializers.zeros),
    tf.keras.layers.Reshape([OUT_STEPS, num_features])
])

co2_history = compile_and_fit(co2_multi_lstm_model, multi_window)

co2_multi_val_performance = {}
co2_multi_performance = {}
co2_multi_val_performance['LSTM'] = co2_multi_lstm_model.evaluate(multi_window.val)
co2_multi_performance['LSTM'] = co2_multi_lstm_model.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/100
# 440/440 [==============================] - 31s 63ms/step - loss: 189518.6719 - mean_absolute_error: 298.0038 - val_loss: 250561.4844 - val_mean_absolute_error: 342.7011
# Epoch 2/100
# 440/440 [==============================] - 27s 62ms/step - loss: 171129.5938 - mean_absolute_error: 282.1248 - val_loss: 229314.2500 - val_mean_absolute_error: 326.7711
# Epoch 3/100
# 440/440 [==============================] - 26s 60ms/step - loss: 154084.5312 - mean_absolute_error: 266.5566 - val_loss: 209856.3438 - val_mean_absolute_error: 311.4691
# Epoch 4/100
# 440/440 [==============================] - 29s 65ms/step - loss: 137843.7188 - mean_absolute_error: 250.8145 - val_loss: 190485.7031 - val_mean_absolute_error: 295.4492
# Epoch 5/100
# 440/440 [==============================] - 27s 61ms/step - loss: 122658.9219 - mean_absolute_error: 235.1512 - val_loss: 172967.3125 - val_mean_absolute_error: 280.1622
# Epoch 6/100
# 440/440 [==============================] - 27s 62ms/step - loss: 109051.1406 - mean_absolute_error: 220.1654 - val_loss: 156935.7031 - val_mean_absolute_error: 265.4068
# Epoch 7/100
# 440/440 [==============================] - 27s 61ms/step - loss: 96619.5312 - mean_absolute_error: 205.5161 - val_loss: 141768.3594 - val_mean_absolute_error: 250.6432
# Epoch 8/100
# 440/440 [==============================] - 30s 68ms/step - loss: 84920.1719 - mean_absolute_error: 190.7014 - val_loss: 127606.4609 - val_mean_absolute_error: 236.0124
# Epoch 9/100
# 440/440 [==============================] - 28s 64ms/step - loss: 74219.9453 - mean_absolute_error: 176.0547 - val_loss: 114256.6016 - val_mean_absolute_error: 221.3613
# Epoch 10/100
# 440/440 [==============================] - 27s 61ms/step - loss: 64531.9180 - mean_absolute_error: 161.6584 - val_loss: 102216.2344 - val_mean_absolute_error: 207.2342
# Epoch 11/100
# 440/440 [==============================] - 27s 61ms/step - loss: 55790.1445 - mean_absolute_error: 147.4506 - val_loss: 90843.0078 - val_mean_absolute_error: 192.9314
# Epoch 12/100
# 440/440 [==============================] - 28s 65ms/step - loss: 48014.8594 - mean_absolute_error: 133.5592 - val_loss: 80863.2734 - val_mean_absolute_error: 179.4381
# Epoch 13/100
# 440/440 [==============================] - 32s 74ms/step - loss: 41287.5820 - mean_absolute_error: 120.2376 - val_loss: 71829.5234 - val_mean_absolute_error: 166.3020
# Epoch 14/100
# 440/440 [==============================] - 26s 59ms/step - loss: 35414.7891 - mean_absolute_error: 107.2532 - val_loss: 63706.4141 - val_mean_absolute_error: 153.4837
# Epoch 15/100
# 440/440 [==============================] - 27s 62ms/step - loss: 30358.0898 - mean_absolute_error: 94.6481 - val_loss: 56457.7344 - val_mean_absolute_error: 141.0972
# Epoch 16/100
# 440/440 [==============================] - 30s 69ms/step - loss: 26072.9336 - mean_absolute_error: 82.4874 - val_loss: 50058.3594 - val_mean_absolute_error: 129.1425
# Epoch 17/100
# 440/440 [==============================] - 32s 72ms/step - loss: 22518.6973 - mean_absolute_error: 72.2387 - val_loss: 44462.4336 - val_mean_absolute_error: 117.7316
# Epoch 18/100
# 440/440 [==============================] - 29s 66ms/step - loss: 19641.0859 - mean_absolute_error: 65.9523 - val_loss: 39654.8711 - val_mean_absolute_error: 108.7200
# Epoch 19/100
# 440/440 [==============================] - 30s 68ms/step - loss: 17384.8535 - mean_absolute_error: 62.7251 - val_loss: 35578.0156 - val_mean_absolute_error: 101.9333
# Epoch 20/100
# 440/440 [==============================] - 27s 62ms/step - loss: 15684.5342 - mean_absolute_error: 61.3144 - val_loss: 32192.1855 - val_mean_absolute_error: 96.7413
# Epoch 21/100
# 440/440 [==============================] - 26s 59ms/step - loss: 14467.2236 - mean_absolute_error: 61.0462 - val_loss: 29451.5293 - val_mean_absolute_error: 92.7297
# Epoch 22/100
# 440/440 [==============================] - 29s 65ms/step - loss: 13654.3428 - mean_absolute_error: 61.4188 - val_loss: 27309.2695 - val_mean_absolute_error: 89.7303
# Epoch 23/100
# 440/440 [==============================] - 31s 69ms/step - loss: 13155.2129 - mean_absolute_error: 62.2016 - val_loss: 25695.0684 - val_mean_absolute_error: 87.5098
# Epoch 24/100
# 440/440 [==============================] - 29s 65ms/step - loss: 12881.1406 - mean_absolute_error: 63.1398 - val_loss: 24542.6289 - val_mean_absolute_error: 85.9365
# Epoch 25/100
# 440/440 [==============================] - 26s 58ms/step - loss: 12748.7139 - mean_absolute_error: 63.9879 - val_loss: 23766.4922 - val_mean_absolute_error: 84.8577
# Epoch 26/100
# 440/440 [==============================] - 29s 66ms/step - loss: 12694.1846 - mean_absolute_error: 64.6251 - val_loss: 23291.0234 - val_mean_absolute_error: 84.2046
# Epoch 27/100
# 440/440 [==============================] - 30s 67ms/step - loss: 12675.1299 - mean_absolute_error: 65.0478 - val_loss: 23023.0215 - val_mean_absolute_error: 83.8318
# Epoch 28/100
# 440/440 [==============================] - 28s 63ms/step - loss: 12669.9639 - mean_absolute_error: 65.2773 - val_loss: 22875.5391 - val_mean_absolute_error: 83.6178
# Epoch 29/100
# 440/440 [==============================] - 28s 63ms/step - loss: 12668.8105 - mean_absolute_error: 65.3857 - val_loss: 22831.9609 - val_mean_absolute_error: 83.5696
# Epoch 30/100
# 440/440 [==============================] - 29s 66ms/step - loss: 12668.4668 - mean_absolute_error: 65.4306 - val_loss: 22816.4844 - val_mean_absolute_error: 83.5429
# Epoch 31/100
# 440/440 [==============================] - 26s 59ms/step - loss: 12668.2783 - mean_absolute_error: 65.4505 - val_loss: 22797.6133 - val_mean_absolute_error: 83.5046
# Epoch 32/100
# 440/440 [==============================] - 28s 64ms/step - loss: 12668.3086 - mean_absolute_error: 65.4634 - val_loss: 22791.4785 - val_mean_absolute_error: 83.5157
# Epoch 33/100
# 440/440 [==============================] - 30s 68ms/step - loss: 12668.3721 - mean_absolute_error: 65.4692 - val_loss: 22799.1270 - val_mean_absolute_error: 83.5220
# Epoch 34/100
# 440/440 [==============================] - 27s 62ms/step - loss: 12668.2744 - mean_absolute_error: 65.4611 - val_loss: 22798.1582 - val_mean_absolute_error: 83.5166
# Epoch 35/100
# 440/440 [==============================] - 42s 95ms/step - loss: 12668.4746 - mean_absolute_error: 65.4653 - val_loss: 22793.2168 - val_mean_absolute_error: 83.5144
# Epoch 36/100
# 440/440 [==============================] - 29s 66ms/step - loss: 12668.4873 - mean_absolute_error: 65.4674 - val_loss: 22793.5215 - val_mean_absolute_error: 83.5055
# Epoch 37/100
# 440/440 [==============================] - 27s 62ms/step - loss: 12668.3428 - mean_absolute_error: 65.4536 - val_loss: 22801.4355 - val_mean_absolute_error: 83.5252
# 125/125 [==============================] - 4s 25ms/step - loss: 22801.4355 - mean_absolute_error: 83.5253

# %%
co2_multi_lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               67072
#
#  dense (Dense)               (None, 20)                2580
#
#  reshape (Reshape)           (None, 10, 2)             0
#
# =================================================================
# Total params: 69,652
# Trainable params: 69,652
# Non-trainable params: 0
# _________________________________________________________________

# %%
multi_window.co2_plot(co2_multi_lstm_model)

# %%
multi_window.changepeople_plot(co2_multi_lstm_model)

# %%
co2_multi_lstm_model.evaluate(multi_window.test)
# Out:
# 62/62 [==============================] - 1s 20ms/step - loss: 31257.5039 - mean_absolute_error: 100.4781
# [31257.50390625, 100.47814178466797]

# %%
print('_________________________________________________________________')
print('Model evaluate')
print('=================================================================')
print('Loss: ', co2_multi_performance['LSTM'][0])
print('MAE(Mean Absolute Error): ', co2_multi_performance['LSTM'][1])
print('=================================================================')
# Out:
# _________________________________________________________________
# Model evaluate
# =================================================================
# Loss:  31257.505859375
# MAE(Mean Absolute Error):  100.4781265258789
# =================================================================

# %%
# 6 훈련 과정 시각화 (MAE)
plt.plot(co2_history.history['mean_absolute_error'])
plt.plot(co2_history.history['val_mean_absolute_error'])
plt.title('Model MAE(mean absolute error)')
plt.xlabel('Epoch')
plt.ylabel('mean_absolute_error')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# 7 훈련 과정 시각화 (손실)
plt.plot(co2_history.history['loss'])
plt.plot(co2_history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# # 모델 저장
# co2_multi_lstm_model.save('co2_multi_lstm_model.h5')
